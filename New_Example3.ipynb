# %%
import jax.numpy as np
import jax
from jax import grad, jacfwd, hessian, jacrev
from jax import vmap
from jax import jit
from jax import random
from jax.lax import cond 
import numpy
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
def sigmoid(x):
    #return x/(1. + np.exp(-x))
    #return np.tanh(x)
    return 1./(1. + np.exp(-x))

# %%
def nn_V(params, t, c):
    M0 = c['M0']
    M1 = c['M1']
    M2 = c['M2']
    #t = (t/c['t1'] -0.5)*2.
    t = (t - c['t0'])/(c['t1']- c['t0']) -0.5
    w0 = params[:M0]#np.reshape(params[:M0], (1, M0))
    b0 = params[M0:2*M0]
    w1 = np.reshape(params[2*M0: 2*M0 + M0*M1], (M0, M1))
    b1 = params[2*M0 + M0*M1: 2*M0 + M0*M1 + M1]
    w2 = np.reshape(params[2*M0 + M0*M1 + M1: 2*M0 + M0*M1 + M1 + M1*M2], (M1, M2))
    b2 = params[2*M0 + M0*M1 + M1 + M1*M2 : 2*M0 + M0*M1 + M1 + M1*M2+M2]
    w3 = np.reshape(params[2*M0 + M0*M1 + M1 + M1*M2+M2:2*M0 + M0*M1 + M1 + M1*M2+M2+4*M2], (M2, 4))
    b3 = params[2*M0 + M0*M1 + M1 + M1*M2+M2+4*M2 : 2*M0 + M0*M1 + M1 + M1*M2+M2+4*M2+4]

    t0 = sigmoid(np.tensordot(t, w0, 0, precision=jax.lax.Precision.HIGHEST) + b0)
    #t0 = sigmoid(np.dot(t, w0) + b0)
    t1 = sigmoid(np.dot(t0, w1) + b1)
    t2 = sigmoid(np.dot(t1, w2) + b2) #+ t0
    t3 = np.dot(t2, w3) + b3 
    res = np.array([c['ics'][0] + (t+0.5)*t3[0],
                    c['ics'][1] + (t+0.5)*t3[1], 
                    (0.5-t)*t3[2], (0.5-t)*t3[3]]) #phi, rho, l1,l2
    return res

v_nn_V = jax.vmap(nn_V, (None, 0, None))
dNNdt_V = jacrev(nn_V, 1)#jacrev(nn, 1)
v_dNNdt_V = jax.vmap(dNNdt_V, (None, 0, None), 0)

# %%
def loss(params, t, c):
    M0 = c['M0']
    M1 = c['M1']
    M2 = c['M2']
    vals = v_nn_V(params, t, c)
    phi = vals[:, 0]
    rho = vals[:, 1]
    L1 = vals[:, 2]
    L2 = vals[:, 3]

    tmp = v_dNNdt_V(params, t, c)
    dphi = tmp[:, 0]
    drho = tmp[:, 1]
    dL1 = tmp[:, 2]
    dL2 = tmp[:, 3]

    H0 = L2*(-c['k']*rho + c['N']*phi*(1.-0.)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - rho/c['rhoMax'] * phi*(1.-0.)*c['v'])
    H1 = L2*(-c['k']*rho + c['N']*phi*(1.-0.9)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - phi*0.9*0.9 - rho/c['rhoMax'] * phi*(1.-0.9)*c['v'])

    utest = np.clip(0.5*(-L2*c['N']*c['rhoMax'] + rho*c['v'] - c['n']*rho*c['v'] + c['n']*L1*rho*c['v'])/(c['rhoMax']*(1. - c['n']+ c['n']*L1)),0., 0.9)
    Hu = L2*(-c['k']*rho + c['N']*phi*(1-utest)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - phi*utest*utest - rho/c['rhoMax'] * phi*(1.-utest)*c['v'])

    #u = np.zeros(len(utest)) - 2.0
    u = np.where(H0 > H1, np.zeros(len(utest)), np.ones(len(utest)) - 0.1)

    H = np.where(H0 > H1, H0, H1)

    
    u = np.where(Hu >= H, utest, u)
    #u = np.where(u > Hu, u, utest)
    res = 0.
    res += (dphi - (-c['b']*phi + c['n']*(c['z']*phi - phi*u*u - rho/c['rhoMax'] * phi*(1.-u)*c['v'])))**2
    res += (drho - (-c['k']*rho + c['N']*phi*(1.-u)))**2

    res += (dL1 + (L2*c['N']*(1.-u) - c['b']*L1 + 
                   (1.-c['n']+c['n']*L1)*(c['z'] - u*u - rho/c['rhoMax'] * (1.-u)*c['v'])))**2
    res += (dL2 + (-L2*c['k'] - 
                   ((1.-c['n']+c['n']*L1)*phi*(1.-u)*c['v'])/c['rhoMax']))**2
    
    return res.mean()

dLoss = grad(loss, 0)

# %%
#consts = {'N':3., 'M0':4, 'M1': 16, 'M2': 64, 'ics': [1., 0.], 't0':0., 't1':1., 'rhoMax': 1., 'b': 0.5, 'n': 0.5, 'k':0.5, 'z': 0.1, 'v':1.0}
consts = {'N':1, 'M0':4, 'M1': 32, 'M2': 128, 'ics': [1., 0.], 't0':0., 't1':7., 'rhoMax': 1., 'b': 0.5, 'n': 0.5, 'k':0.5, 'z': 1.0, 'v':1.0}

# %%
inputs = np.linspace(consts['t0'], consts['t1'], num=5000)
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
epochs = 2500

learning_rate = 0.01
#inputs = np.linspace(np.array([0., 1e-4]), np.array([consts['t1']-1e-4, consts['ics'][0]]), num=501)
batch_size = 500
key = random.PRNGKey(0)
M0 = consts['M0']
M1 = consts['M1']
M2 = consts['M2']
params = (random.normal(key, shape=(2*M0 + M0*M1 + M1 + M1*M2+M2+4*M2+4, )))*0.1
#params = params - params.min()
#params /= params.max()
v = 0.0
m = 0.0
b1 = 0.9
b2 = 0.999
bestLoss = 1000000.0
bestParams = params
ec = 1

# %%
bad_ep = 0
step = -1e-4
k = 0
PastParams = params
max_lr=0.2
for epoch in range(epochs):
    i = numpy.random.randint(0, inputs.shape[0], size=batch_size)
    #sample = inputs[i]
    sample = inputs
    #rnd = (numpy.random.random(batch_size)-0.5 )*0.1
    #rnd = numpy.clip(rnd, -0.0005, 0.0005)
    #sample += rnd
    #sample = numpy.clip(sample, consts['t0'], consts['t1'] - 1e-4)
    #assert numpy.array(sample).min() >=0 and numpy.array(sample).max() <= 1.
    #print(sample)
    #learning_rate = learning_rate * 0.999
    learning_rate = learning_rate + step
    #if bad_ep >= 50:
      #k = 250
      #learning_rate = learning_rate + step
      #bad_ep = 0
    if learning_rate <= 1e-8:
      step= 1e-2
      #PastParams = PastParams + 0.75*(params - PastParams)
      #k = 0
      #params = PastParams
      #v = 0.0
      #m = 0.0

    if learning_rate >= max_lr:
      step = -1e-3
    if epoch % ec == 0:
      currLoss = loss(params, inputs, consts)
      #print('epoch: %3d loss: %.6f lr: %.6f', (epoch, currLoss, learning_rate) )
      if currLoss < bestLoss:
        print('epoch: %3d loss: %.6f lr: %.6f', (epoch, currLoss, learning_rate) )
        print('Loss Updated!')
        print(' ')
        bestParams = params
        bestLoss = currLoss
        bad_ep = 0
      else:
        bad_ep += 1
      #  if bad_ep >= 50:
      #    learning_rate = learning_rate * 0.1
      #    if learning_rate <= 1e-5:
      #      break

         # bad_ep=0

    gradient = dLoss(params, sample, consts)# + momentum*velocity
    m = b1*m + (1. -b1)* gradient
    v = b2*v + (1.-b2)*(np.square(gradient))
    m0 = m / (1. -b1)
    v0 = v / (1. -b2)
    velocity = - learning_rate*(m0 / (np.sqrt(v0) + 1e-8))##*gradient#
    params += velocity

    k += 1
    if k == 200:
      PastParams = PastParams + 0.5*(params - PastParams)
      k = 0
      params = PastParams
      #max_lr = max(0.99*max_lr, 0.1)
# Out:
# epoch: %3d loss: %.6f lr: %.6f (0, DeviceArray(2.0955207, dtype=float32), 0.0099)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (1, DeviceArray(0.35213363, dtype=float32), 0.009800000000000001)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (6, DeviceArray(0.27780947, dtype=float32), 0.009300000000000004)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (10, DeviceArray(0.08961531, dtype=float32), 0.008900000000000007)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (19, DeviceArray(0.0859016, dtype=float32), 0.008000000000000012)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (20, DeviceArray(0.08286388, dtype=float32), 0.007900000000000013)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (27, DeviceArray(0.07492512, dtype=float32), 0.007200000000000011)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (28, DeviceArray(0.06064956, dtype=float32), 0.007100000000000011)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (29, DeviceArray(0.05678758, dtype=float32), 0.0070000000000000106)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (37, DeviceArray(0.05504221, dtype=float32), 0.0062000000000000085)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (38, DeviceArray(0.05291298, dtype=float32), 0.006100000000000008)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (39, DeviceArray(0.05234415, dtype=float32), 0.006000000000000008)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (42, DeviceArray(0.05227258, dtype=float32), 0.005700000000000007)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (48, DeviceArray(0.05198317, dtype=float32), 0.005100000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (49, DeviceArray(0.05036863, dtype=float32), 0.005000000000000005)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (50, DeviceArray(0.04899006, dtype=float32), 0.004900000000000005)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (51, DeviceArray(0.04817218, dtype=float32), 0.004800000000000005)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (52, DeviceArray(0.04796651, dtype=float32), 0.0047000000000000045)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (63, DeviceArray(0.0479331, dtype=float32), 0.0036000000000000034)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (64, DeviceArray(0.0478906, dtype=float32), 0.0035000000000000035)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (65, DeviceArray(0.04785955, dtype=float32), 0.0034000000000000037)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (66, DeviceArray(0.04782877, dtype=float32), 0.003300000000000004)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (67, DeviceArray(0.04779736, dtype=float32), 0.003200000000000004)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (68, DeviceArray(0.0477706, dtype=float32), 0.0031000000000000042)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (69, DeviceArray(0.04775457, dtype=float32), 0.0030000000000000044)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (70, DeviceArray(0.04775207, dtype=float32), 0.0029000000000000046)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (77, DeviceArray(0.04773902, dtype=float32), 0.0022000000000000058)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (78, DeviceArray(0.04770537, dtype=float32), 0.002100000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (79, DeviceArray(0.04767073, dtype=float32), 0.002000000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (80, DeviceArray(0.04763879, dtype=float32), 0.001900000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (81, DeviceArray(0.047612, dtype=float32), 0.001800000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (82, DeviceArray(0.04759147, dtype=float32), 0.001700000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (83, DeviceArray(0.04757717, dtype=float32), 0.001600000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (84, DeviceArray(0.0475683, dtype=float32), 0.0015000000000000059)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (85, DeviceArray(0.04756361, dtype=float32), 0.0014000000000000058)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (86, DeviceArray(0.04756182, dtype=float32), 0.0013000000000000058)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (87, DeviceArray(0.04756177, dtype=float32), 0.0012000000000000057)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (101, DeviceArray(0.04755741, dtype=float32), 0.020000000000000004)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (471, DeviceArray(0.04755733, dtype=float32), 0.07899999999999979)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (472, DeviceArray(0.04755575, dtype=float32), 0.07799999999999979)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (473, DeviceArray(0.0475555, dtype=float32), 0.07699999999999979)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (484, DeviceArray(0.0475554, dtype=float32), 0.06599999999999978)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (485, DeviceArray(0.04755459, dtype=float32), 0.06499999999999978)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (486, DeviceArray(0.04755397, dtype=float32), 0.06399999999999978)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (487, DeviceArray(0.04755354, dtype=float32), 0.06299999999999978)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (488, DeviceArray(0.04755328, dtype=float32), 0.06199999999999978)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (489, DeviceArray(0.04755316, dtype=float32), 0.06099999999999978)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (490, DeviceArray(0.04755313, dtype=float32), 0.059999999999999776)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (495, DeviceArray(0.04755308, dtype=float32), 0.05499999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (496, DeviceArray(0.04755294, dtype=float32), 0.05399999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (497, DeviceArray(0.04755276, dtype=float32), 0.05299999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (498, DeviceArray(0.04755256, dtype=float32), 0.05199999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (499, DeviceArray(0.04755232, dtype=float32), 0.05099999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (500, DeviceArray(0.04755209, dtype=float32), 0.04999999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (501, DeviceArray(0.04755186, dtype=float32), 0.048999999999999766)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (502, DeviceArray(0.04755164, dtype=float32), 0.047999999999999765)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (503, DeviceArray(0.04755145, dtype=float32), 0.046999999999999764)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (504, DeviceArray(0.04755129, dtype=float32), 0.04599999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (505, DeviceArray(0.04755116, dtype=float32), 0.04499999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (506, DeviceArray(0.04755104, dtype=float32), 0.04399999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (507, DeviceArray(0.04755096, dtype=float32), 0.04299999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (508, DeviceArray(0.04755089, dtype=float32), 0.04199999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (509, DeviceArray(0.04755083, dtype=float32), 0.04099999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (510, DeviceArray(0.04755079, dtype=float32), 0.03999999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (511, DeviceArray(0.04755075, dtype=float32), 0.03899999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (512, DeviceArray(0.04755072, dtype=float32), 0.037999999999999756)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (513, DeviceArray(0.04755069, dtype=float32), 0.036999999999999755)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (514, DeviceArray(0.04755066, dtype=float32), 0.035999999999999754)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (515, DeviceArray(0.04755062, dtype=float32), 0.034999999999999754)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (516, DeviceArray(0.04755058, dtype=float32), 0.03399999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (517, DeviceArray(0.04755055, dtype=float32), 0.03299999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (518, DeviceArray(0.0475505, dtype=float32), 0.03199999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (519, DeviceArray(0.04755047, dtype=float32), 0.03099999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (520, DeviceArray(0.04755042, dtype=float32), 0.02999999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (521, DeviceArray(0.04755038, dtype=float32), 0.028999999999999748)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (522, DeviceArray(0.04755034, dtype=float32), 0.027999999999999747)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (523, DeviceArray(0.0475503, dtype=float32), 0.026999999999999746)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (524, DeviceArray(0.04755026, dtype=float32), 0.025999999999999746)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (525, DeviceArray(0.04755022, dtype=float32), 0.024999999999999745)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (526, DeviceArray(0.04755018, dtype=float32), 0.023999999999999744)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (527, DeviceArray(0.04755015, dtype=float32), 0.022999999999999743)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (528, DeviceArray(0.04755012, dtype=float32), 0.021999999999999742)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (529, DeviceArray(0.04755008, dtype=float32), 0.02099999999999974)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (530, DeviceArray(0.04755005, dtype=float32), 0.01999999999999974)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (531, DeviceArray(0.04755003, dtype=float32), 0.01899999999999974)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (532, DeviceArray(0.04755, dtype=float32), 0.01799999999999974)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (533, DeviceArray(0.04754997, dtype=float32), 0.016999999999999738)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (534, DeviceArray(0.04754996, dtype=float32), 0.015999999999999737)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (535, DeviceArray(0.04754993, dtype=float32), 0.014999999999999736)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (536, DeviceArray(0.04754991, dtype=float32), 0.013999999999999735)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (537, DeviceArray(0.0475499, dtype=float32), 0.012999999999999734)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (538, DeviceArray(0.04754988, dtype=float32), 0.011999999999999733)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (539, DeviceArray(0.04754986, dtype=float32), 0.010999999999999732)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (540, DeviceArray(0.04754984, dtype=float32), 0.009999999999999731)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (541, DeviceArray(0.04754983, dtype=float32), 0.00899999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (542, DeviceArray(0.04754982, dtype=float32), 0.00799999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (543, DeviceArray(0.04754981, dtype=float32), 0.0069999999999997295)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (544, DeviceArray(0.04754981, dtype=float32), 0.0059999999999997295)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (545, DeviceArray(0.0475498, dtype=float32), 0.0049999999999997295)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (546, DeviceArray(0.04754979, dtype=float32), 0.0039999999999997295)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (548, DeviceArray(0.04754978, dtype=float32), 0.0019999999999997294)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (552, DeviceArray(0.04754977, dtype=float32), 0.01999999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (553, DeviceArray(0.04754974, dtype=float32), 0.02999999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (554, DeviceArray(0.04754969, dtype=float32), 0.03999999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (555, DeviceArray(0.04754965, dtype=float32), 0.04999999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (556, DeviceArray(0.04754959, dtype=float32), 0.059999999999999734)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (557, DeviceArray(0.04754949, dtype=float32), 0.06999999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (558, DeviceArray(0.04754942, dtype=float32), 0.07999999999999972)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (559, DeviceArray(0.04754931, dtype=float32), 0.08999999999999972)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (560, DeviceArray(0.04754919, dtype=float32), 0.09999999999999971)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (561, DeviceArray(0.04754906, dtype=float32), 0.10999999999999971)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (562, DeviceArray(0.04754891, dtype=float32), 0.1199999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (563, DeviceArray(0.04754876, dtype=float32), 0.1299999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (564, DeviceArray(0.04754859, dtype=float32), 0.1399999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (565, DeviceArray(0.0475484, dtype=float32), 0.14999999999999972)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (566, DeviceArray(0.0475482, dtype=float32), 0.15999999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (567, DeviceArray(0.04754798, dtype=float32), 0.16999999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (568, DeviceArray(0.04754775, dtype=float32), 0.17999999999999974)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (569, DeviceArray(0.0475475, dtype=float32), 0.18999999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (570, DeviceArray(0.04754724, dtype=float32), 0.19999999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (571, DeviceArray(0.04754695, dtype=float32), 0.20999999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (572, DeviceArray(0.04754665, dtype=float32), 0.20899999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (573, DeviceArray(0.04754634, dtype=float32), 0.20799999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (574, DeviceArray(0.04754604, dtype=float32), 0.20699999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (575, DeviceArray(0.04754573, dtype=float32), 0.20599999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (576, DeviceArray(0.04754542, dtype=float32), 0.20499999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (577, DeviceArray(0.0475451, dtype=float32), 0.20399999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (578, DeviceArray(0.04754479, dtype=float32), 0.20299999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (579, DeviceArray(0.04754447, dtype=float32), 0.20199999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (580, DeviceArray(0.04754414, dtype=float32), 0.20099999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (581, DeviceArray(0.04754382, dtype=float32), 0.19999999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (582, DeviceArray(0.04754349, dtype=float32), 0.19899999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (583, DeviceArray(0.04754316, dtype=float32), 0.19799999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (584, DeviceArray(0.04754282, dtype=float32), 0.19699999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (585, DeviceArray(0.04754248, dtype=float32), 0.19599999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (586, DeviceArray(0.04754214, dtype=float32), 0.19499999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (587, DeviceArray(0.04754179, dtype=float32), 0.19399999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (588, DeviceArray(0.04754144, dtype=float32), 0.19299999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (589, DeviceArray(0.04754109, dtype=float32), 0.19199999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (590, DeviceArray(0.04754073, dtype=float32), 0.19099999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (591, DeviceArray(0.04754037, dtype=float32), 0.18999999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (592, DeviceArray(0.04754, dtype=float32), 0.18899999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (593, DeviceArray(0.04753963, dtype=float32), 0.18799999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (594, DeviceArray(0.04753926, dtype=float32), 0.18699999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (595, DeviceArray(0.04753887, dtype=float32), 0.18599999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (596, DeviceArray(0.0475385, dtype=float32), 0.18499999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (597, DeviceArray(0.04753811, dtype=float32), 0.18399999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (598, DeviceArray(0.04753771, dtype=float32), 0.18299999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (599, DeviceArray(0.04753732, dtype=float32), 0.18199999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (658, DeviceArray(0.04753304, dtype=float32), 0.12299999999999969)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (659, DeviceArray(0.04753159, dtype=float32), 0.12199999999999969)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (668, DeviceArray(0.04753117, dtype=float32), 0.11299999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (669, DeviceArray(0.04752934, dtype=float32), 0.11199999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (670, DeviceArray(0.0475281, dtype=float32), 0.11099999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (671, DeviceArray(0.04752743, dtype=float32), 0.10999999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (672, DeviceArray(0.04752719, dtype=float32), 0.10899999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (673, DeviceArray(0.04752714, dtype=float32), 0.10799999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (674, DeviceArray(0.04752709, dtype=float32), 0.10699999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (675, DeviceArray(0.04752686, dtype=float32), 0.10599999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (676, DeviceArray(0.04752634, dtype=float32), 0.10499999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (677, DeviceArray(0.04752557, dtype=float32), 0.10399999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (678, DeviceArray(0.0475246, dtype=float32), 0.10299999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (679, DeviceArray(0.04752355, dtype=float32), 0.10199999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (680, DeviceArray(0.04752253, dtype=float32), 0.10099999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (681, DeviceArray(0.04752163, dtype=float32), 0.09999999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (682, DeviceArray(0.04752089, dtype=float32), 0.09899999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (683, DeviceArray(0.04752034, dtype=float32), 0.09799999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (684, DeviceArray(0.04751993, dtype=float32), 0.09699999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (685, DeviceArray(0.04751963, dtype=float32), 0.09599999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (686, DeviceArray(0.04751936, dtype=float32), 0.09499999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (687, DeviceArray(0.04751908, dtype=float32), 0.09399999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (688, DeviceArray(0.04751876, dtype=float32), 0.09299999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (689, DeviceArray(0.04751835, dtype=float32), 0.09199999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (690, DeviceArray(0.04751787, dtype=float32), 0.09099999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (691, DeviceArray(0.04751734, dtype=float32), 0.08999999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (692, DeviceArray(0.04751676, dtype=float32), 0.08899999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (693, DeviceArray(0.04751617, dtype=float32), 0.08799999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (694, DeviceArray(0.04751559, dtype=float32), 0.08699999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (695, DeviceArray(0.04751502, dtype=float32), 0.08599999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (696, DeviceArray(0.04751448, dtype=float32), 0.08499999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (697, DeviceArray(0.04751398, dtype=float32), 0.08399999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (698, DeviceArray(0.0475135, dtype=float32), 0.08299999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (699, DeviceArray(0.04751304, dtype=float32), 0.08199999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (700, DeviceArray(0.04751259, dtype=float32), 0.08099999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (701, DeviceArray(0.04751213, dtype=float32), 0.07999999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (702, DeviceArray(0.04751169, dtype=float32), 0.07899999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (703, DeviceArray(0.04751121, dtype=float32), 0.07799999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (704, DeviceArray(0.04751074, dtype=float32), 0.07699999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (705, DeviceArray(0.04751026, dtype=float32), 0.07599999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (706, DeviceArray(0.04750976, dtype=float32), 0.07499999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (707, DeviceArray(0.04750926, dtype=float32), 0.07399999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (708, DeviceArray(0.04750878, dtype=float32), 0.07299999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (709, DeviceArray(0.04750828, dtype=float32), 0.07199999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (710, DeviceArray(0.0475078, dtype=float32), 0.07099999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (711, DeviceArray(0.04750732, dtype=float32), 0.06999999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (712, DeviceArray(0.04750685, dtype=float32), 0.06899999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (713, DeviceArray(0.04750637, dtype=float32), 0.06799999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (714, DeviceArray(0.04750591, dtype=float32), 0.06699999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (715, DeviceArray(0.04750544, dtype=float32), 0.06599999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (716, DeviceArray(0.04750497, dtype=float32), 0.06499999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (717, DeviceArray(0.0475045, dtype=float32), 0.06399999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (718, DeviceArray(0.04750404, dtype=float32), 0.06299999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (719, DeviceArray(0.04750357, dtype=float32), 0.06199999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (720, DeviceArray(0.0475031, dtype=float32), 0.06099999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (721, DeviceArray(0.04750263, dtype=float32), 0.05999999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (722, DeviceArray(0.04750217, dtype=float32), 0.058999999999999636)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (723, DeviceArray(0.0475017, dtype=float32), 0.057999999999999635)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (724, DeviceArray(0.04750124, dtype=float32), 0.056999999999999634)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (725, DeviceArray(0.04750078, dtype=float32), 0.05599999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (726, DeviceArray(0.04750033, dtype=float32), 0.05499999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (727, DeviceArray(0.04749987, dtype=float32), 0.05399999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (728, DeviceArray(0.04749942, dtype=float32), 0.05299999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (729, DeviceArray(0.04749898, dtype=float32), 0.05199999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (730, DeviceArray(0.04749854, dtype=float32), 0.05099999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (731, DeviceArray(0.0474981, dtype=float32), 0.04999999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (732, DeviceArray(0.04749766, dtype=float32), 0.04899999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (733, DeviceArray(0.04749723, dtype=float32), 0.047999999999999626)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (734, DeviceArray(0.04749681, dtype=float32), 0.046999999999999625)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (735, DeviceArray(0.04749638, dtype=float32), 0.045999999999999625)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (736, DeviceArray(0.04749596, dtype=float32), 0.044999999999999624)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (737, DeviceArray(0.04749555, dtype=float32), 0.04399999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (738, DeviceArray(0.04749514, dtype=float32), 0.04299999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (739, DeviceArray(0.04749474, dtype=float32), 0.04199999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (740, DeviceArray(0.04749434, dtype=float32), 0.04099999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (741, DeviceArray(0.04749395, dtype=float32), 0.03999999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (742, DeviceArray(0.04749356, dtype=float32), 0.03899999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (743, DeviceArray(0.04749317, dtype=float32), 0.03799999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (744, DeviceArray(0.0474928, dtype=float32), 0.036999999999999617)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (745, DeviceArray(0.04749243, dtype=float32), 0.035999999999999616)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (746, DeviceArray(0.04749207, dtype=float32), 0.034999999999999615)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (747, DeviceArray(0.04749171, dtype=float32), 0.033999999999999614)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (748, DeviceArray(0.04749136, dtype=float32), 0.03299999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (749, DeviceArray(0.04749102, dtype=float32), 0.03199999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (750, DeviceArray(0.04749068, dtype=float32), 0.03099999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (751, DeviceArray(0.04749035, dtype=float32), 0.02999999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (752, DeviceArray(0.04749003, dtype=float32), 0.02899999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (753, DeviceArray(0.04748973, dtype=float32), 0.02799999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (754, DeviceArray(0.04748943, dtype=float32), 0.026999999999999608)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (755, DeviceArray(0.04748913, dtype=float32), 0.025999999999999607)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (756, DeviceArray(0.04748885, dtype=float32), 0.024999999999999606)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (757, DeviceArray(0.04748857, dtype=float32), 0.023999999999999605)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (758, DeviceArray(0.0474883, dtype=float32), 0.022999999999999604)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (759, DeviceArray(0.04748804, dtype=float32), 0.021999999999999603)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (760, DeviceArray(0.04748779, dtype=float32), 0.020999999999999602)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (761, DeviceArray(0.04748755, dtype=float32), 0.0199999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (762, DeviceArray(0.04748733, dtype=float32), 0.0189999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (763, DeviceArray(0.0474871, dtype=float32), 0.0179999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (764, DeviceArray(0.0474869, dtype=float32), 0.0169999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (765, DeviceArray(0.0474867, dtype=float32), 0.015999999999999598)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (766, DeviceArray(0.04748651, dtype=float32), 0.014999999999999597)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (767, DeviceArray(0.04748634, dtype=float32), 0.013999999999999596)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (768, DeviceArray(0.04748617, dtype=float32), 0.012999999999999595)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (769, DeviceArray(0.04748602, dtype=float32), 0.011999999999999594)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (770, DeviceArray(0.04748587, dtype=float32), 0.010999999999999593)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (771, DeviceArray(0.04748574, dtype=float32), 0.009999999999999593)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (772, DeviceArray(0.04748562, dtype=float32), 0.008999999999999592)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (773, DeviceArray(0.04748551, dtype=float32), 0.00799999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (774, DeviceArray(0.04748541, dtype=float32), 0.006999999999999591)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (775, DeviceArray(0.04748533, dtype=float32), 0.005999999999999591)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (776, DeviceArray(0.04748525, dtype=float32), 0.004999999999999591)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (777, DeviceArray(0.04748519, dtype=float32), 0.003999999999999591)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (778, DeviceArray(0.04748514, dtype=float32), 0.0029999999999995907)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (779, DeviceArray(0.04748511, dtype=float32), 0.0019999999999995906)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (780, DeviceArray(0.04748509, dtype=float32), 0.0009999999999995906)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (781, DeviceArray(0.04748506, dtype=float32), -4.0939474033052647e-16)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (783, DeviceArray(0.04748494, dtype=float32), 0.01999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (784, DeviceArray(0.04748469, dtype=float32), 0.02999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (785, DeviceArray(0.04748432, dtype=float32), 0.03999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (786, DeviceArray(0.04748381, dtype=float32), 0.04999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (787, DeviceArray(0.04748318, dtype=float32), 0.059999999999999595)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (788, DeviceArray(0.0474824, dtype=float32), 0.06999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (789, DeviceArray(0.04748149, dtype=float32), 0.07999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (790, DeviceArray(0.04748043, dtype=float32), 0.08999999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (791, DeviceArray(0.04747922, dtype=float32), 0.09999999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (792, DeviceArray(0.04747785, dtype=float32), 0.10999999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (793, DeviceArray(0.04747631, dtype=float32), 0.11999999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (794, DeviceArray(0.0474746, dtype=float32), 0.12999999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (795, DeviceArray(0.04747269, dtype=float32), 0.13999999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (796, DeviceArray(0.04747058, dtype=float32), 0.14999999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (797, DeviceArray(0.04746825, dtype=float32), 0.1599999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (798, DeviceArray(0.04746567, dtype=float32), 0.1699999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (799, DeviceArray(0.04746283, dtype=float32), 0.1799999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (837, DeviceArray(0.04744858, dtype=float32), 0.1749999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (838, DeviceArray(0.04742677, dtype=float32), 0.1739999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (839, DeviceArray(0.04741146, dtype=float32), 0.1729999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (840, DeviceArray(0.04740483, dtype=float32), 0.1719999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (844, DeviceArray(0.04740228, dtype=float32), 0.1679999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (845, DeviceArray(0.04739048, dtype=float32), 0.1669999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (846, DeviceArray(0.04737427, dtype=float32), 0.1659999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (847, DeviceArray(0.04735676, dtype=float32), 0.1649999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (848, DeviceArray(0.0473408, dtype=float32), 0.1639999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (849, DeviceArray(0.04732789, dtype=float32), 0.1629999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (850, DeviceArray(0.04731787, dtype=float32), 0.1619999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (851, DeviceArray(0.04730926, dtype=float32), 0.1609999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (852, DeviceArray(0.04730023, dtype=float32), 0.1599999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (853, DeviceArray(0.04728932, dtype=float32), 0.15899999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (854, DeviceArray(0.04727612, dtype=float32), 0.15799999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (855, DeviceArray(0.04726121, dtype=float32), 0.15699999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (856, DeviceArray(0.04724583, dtype=float32), 0.15599999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (857, DeviceArray(0.04723121, dtype=float32), 0.15499999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (858, DeviceArray(0.04721794, dtype=float32), 0.15399999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (859, DeviceArray(0.04720568, dtype=float32), 0.15299999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (860, DeviceArray(0.04719331, dtype=float32), 0.15199999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (861, DeviceArray(0.04717956, dtype=float32), 0.15099999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (862, DeviceArray(0.0471637, dtype=float32), 0.14999999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (863, DeviceArray(0.04714597, dtype=float32), 0.14899999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (864, DeviceArray(0.04712735, dtype=float32), 0.14799999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (865, DeviceArray(0.04710894, dtype=float32), 0.14699999999999958)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (866, DeviceArray(0.04709122, dtype=float32), 0.14599999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (867, DeviceArray(0.04707389, dtype=float32), 0.14499999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (868, DeviceArray(0.04705617, dtype=float32), 0.14399999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (869, DeviceArray(0.04703736, dtype=float32), 0.14299999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (870, DeviceArray(0.04701719, dtype=float32), 0.14199999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (871, DeviceArray(0.04699596, dtype=float32), 0.14099999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (872, DeviceArray(0.04697429, dtype=float32), 0.13999999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (873, DeviceArray(0.04695256, dtype=float32), 0.13899999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (874, DeviceArray(0.04693073, dtype=float32), 0.13799999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (875, DeviceArray(0.0469083, dtype=float32), 0.13699999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (876, DeviceArray(0.04688472, dtype=float32), 0.13599999999999957)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (877, DeviceArray(0.04685976, dtype=float32), 0.13499999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (878, DeviceArray(0.04683369, dtype=float32), 0.13399999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (879, DeviceArray(0.04680689, dtype=float32), 0.13299999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (880, DeviceArray(0.04677958, dtype=float32), 0.13199999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (881, DeviceArray(0.04675163, dtype=float32), 0.13099999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (882, DeviceArray(0.04672275, dtype=float32), 0.12999999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (883, DeviceArray(0.04669275, dtype=float32), 0.12899999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (884, DeviceArray(0.04666167, dtype=float32), 0.12799999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (885, DeviceArray(0.04662979, dtype=float32), 0.12699999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (886, DeviceArray(0.04659724, dtype=float32), 0.12599999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (887, DeviceArray(0.04656398, dtype=float32), 0.12499999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (888, DeviceArray(0.04652976, dtype=float32), 0.12399999999999956)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (889, DeviceArray(0.04649438, dtype=float32), 0.12299999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (890, DeviceArray(0.04645786, dtype=float32), 0.12199999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (891, DeviceArray(0.04642038, dtype=float32), 0.12099999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (892, DeviceArray(0.0463821, dtype=float32), 0.11999999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (893, DeviceArray(0.04634301, dtype=float32), 0.11899999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (894, DeviceArray(0.04630296, dtype=float32), 0.11799999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (895, DeviceArray(0.04626185, dtype=float32), 0.11699999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (896, DeviceArray(0.04621972, dtype=float32), 0.11599999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (897, DeviceArray(0.04617665, dtype=float32), 0.11499999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (898, DeviceArray(0.04613264, dtype=float32), 0.11399999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (899, DeviceArray(0.04608757, dtype=float32), 0.11299999999999955)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (900, DeviceArray(0.0460413, dtype=float32), 0.11199999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (901, DeviceArray(0.04599383, dtype=float32), 0.11099999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (902, DeviceArray(0.04594525, dtype=float32), 0.10999999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (903, DeviceArray(0.04589558, dtype=float32), 0.10899999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (904, DeviceArray(0.0458448, dtype=float32), 0.10799999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (905, DeviceArray(0.04579282, dtype=float32), 0.10699999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (906, DeviceArray(0.04573965, dtype=float32), 0.10599999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (907, DeviceArray(0.0456853, dtype=float32), 0.10499999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (908, DeviceArray(0.04562978, dtype=float32), 0.10399999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (909, DeviceArray(0.04557304, dtype=float32), 0.10299999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (910, DeviceArray(0.04551496, dtype=float32), 0.10199999999999954)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (911, DeviceArray(0.04545553, dtype=float32), 0.10099999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (912, DeviceArray(0.04539476, dtype=float32), 0.09999999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (913, DeviceArray(0.0453326, dtype=float32), 0.09899999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (914, DeviceArray(0.04526899, dtype=float32), 0.09799999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (915, DeviceArray(0.04520386, dtype=float32), 0.09699999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (916, DeviceArray(0.04513712, dtype=float32), 0.09599999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (917, DeviceArray(0.04506875, dtype=float32), 0.09499999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (918, DeviceArray(0.04499867, dtype=float32), 0.09399999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (919, DeviceArray(0.04492676, dtype=float32), 0.09299999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (920, DeviceArray(0.04485296, dtype=float32), 0.09199999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (921, DeviceArray(0.0447772, dtype=float32), 0.09099999999999953)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (922, DeviceArray(0.04469943, dtype=float32), 0.08999999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (923, DeviceArray(0.04461953, dtype=float32), 0.08899999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (924, DeviceArray(0.04453743, dtype=float32), 0.08799999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (925, DeviceArray(0.04445304, dtype=float32), 0.08699999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (926, DeviceArray(0.04436629, dtype=float32), 0.08599999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (927, DeviceArray(0.04427706, dtype=float32), 0.08499999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (928, DeviceArray(0.04418526, dtype=float32), 0.08399999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (929, DeviceArray(0.04409077, dtype=float32), 0.08299999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (930, DeviceArray(0.04399352, dtype=float32), 0.08199999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (931, DeviceArray(0.04389338, dtype=float32), 0.08099999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (932, DeviceArray(0.04379024, dtype=float32), 0.07999999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (933, DeviceArray(0.04368395, dtype=float32), 0.07899999999999952)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (934, DeviceArray(0.04357443, dtype=float32), 0.07799999999999951)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (935, DeviceArray(0.04346151, dtype=float32), 0.07699999999999951)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (936, DeviceArray(0.04334507, dtype=float32), 0.07599999999999951)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (937, DeviceArray(0.04322495, dtype=float32), 0.07499999999999951)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (938, DeviceArray(0.04310102, dtype=float32), 0.07399999999999951)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (939, DeviceArray(0.04297315, dtype=float32), 0.07299999999999951)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (940, DeviceArray(0.04284117, dtype=float32), 0.07199999999999951)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (941, DeviceArray(0.04270494, dtype=float32), 0.07099999999999951)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (942, DeviceArray(0.04256431, dtype=float32), 0.06999999999999951)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (943, DeviceArray(0.04241911, dtype=float32), 0.0689999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (944, DeviceArray(0.04226919, dtype=float32), 0.0679999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (945, DeviceArray(0.0421144, dtype=float32), 0.0669999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (946, DeviceArray(0.04195456, dtype=float32), 0.0659999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (947, DeviceArray(0.04178955, dtype=float32), 0.0649999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (948, DeviceArray(0.04161919, dtype=float32), 0.0639999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (949, DeviceArray(0.04144333, dtype=float32), 0.0629999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (950, DeviceArray(0.04126183, dtype=float32), 0.0619999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (951, DeviceArray(0.04107454, dtype=float32), 0.0609999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (952, DeviceArray(0.04088133, dtype=float32), 0.0599999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (953, DeviceArray(0.04068207, dtype=float32), 0.0589999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (954, DeviceArray(0.04047664, dtype=float32), 0.057999999999999496)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (955, DeviceArray(0.04026494, dtype=float32), 0.056999999999999496)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (956, DeviceArray(0.0400469, dtype=float32), 0.055999999999999495)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (957, DeviceArray(0.03982243, dtype=float32), 0.054999999999999494)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (958, DeviceArray(0.03959149, dtype=float32), 0.05399999999999949)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (959, DeviceArray(0.03935405, dtype=float32), 0.05299999999999949)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (960, DeviceArray(0.0391101, dtype=float32), 0.05199999999999949)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (961, DeviceArray(0.03885967, dtype=float32), 0.05099999999999949)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (962, DeviceArray(0.03860281, dtype=float32), 0.04999999999999949)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (963, DeviceArray(0.03833961, dtype=float32), 0.04899999999999949)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (964, DeviceArray(0.03807018, dtype=float32), 0.04799999999999949)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (965, DeviceArray(0.03779469, dtype=float32), 0.04699999999999949)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (966, DeviceArray(0.03751333, dtype=float32), 0.045999999999999486)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (967, DeviceArray(0.03722633, dtype=float32), 0.044999999999999485)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (968, DeviceArray(0.03693397, dtype=float32), 0.043999999999999484)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (969, DeviceArray(0.03663656, dtype=float32), 0.04299999999999948)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (970, DeviceArray(0.03633447, dtype=float32), 0.04199999999999948)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (971, DeviceArray(0.03602812, dtype=float32), 0.04099999999999948)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (972, DeviceArray(0.03571794, dtype=float32), 0.03999999999999948)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (973, DeviceArray(0.03540444, dtype=float32), 0.03899999999999948)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (974, DeviceArray(0.03508815, dtype=float32), 0.03799999999999948)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (975, DeviceArray(0.03476964, dtype=float32), 0.03699999999999948)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (976, DeviceArray(0.03444953, dtype=float32), 0.03599999999999948)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (977, DeviceArray(0.03412847, dtype=float32), 0.034999999999999476)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (978, DeviceArray(0.03380713, dtype=float32), 0.033999999999999475)
# Loss Updated!
#
# ...
#
# epoch: %3d loss: %.6f lr: %.6f (2260, DeviceArray(0.0014354, dtype=float32), 0.13799999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2261, DeviceArray(0.001432, dtype=float32), 0.13699999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2262, DeviceArray(0.00142867, dtype=float32), 0.13599999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2263, DeviceArray(0.00142546, dtype=float32), 0.13499999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2264, DeviceArray(0.00142225, dtype=float32), 0.13399999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2265, DeviceArray(0.00141903, dtype=float32), 0.13299999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2266, DeviceArray(0.00141599, dtype=float32), 0.13199999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2267, DeviceArray(0.00141288, dtype=float32), 0.13099999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2268, DeviceArray(0.00140986, dtype=float32), 0.12999999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2269, DeviceArray(0.00140692, dtype=float32), 0.12899999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2270, DeviceArray(0.00140394, dtype=float32), 0.12799999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2271, DeviceArray(0.00140107, dtype=float32), 0.12699999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2272, DeviceArray(0.00139821, dtype=float32), 0.12599999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2273, DeviceArray(0.00139539, dtype=float32), 0.12499999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2274, DeviceArray(0.00139264, dtype=float32), 0.12399999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2275, DeviceArray(0.0013899, dtype=float32), 0.12299999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2276, DeviceArray(0.0013872, dtype=float32), 0.12199999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2277, DeviceArray(0.00138456, dtype=float32), 0.12099999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2278, DeviceArray(0.00138194, dtype=float32), 0.11999999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2279, DeviceArray(0.00137936, dtype=float32), 0.11899999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2280, DeviceArray(0.00137682, dtype=float32), 0.11799999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2281, DeviceArray(0.00137431, dtype=float32), 0.11699999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2282, DeviceArray(0.00137185, dtype=float32), 0.11599999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2283, DeviceArray(0.00136941, dtype=float32), 0.11499999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2284, DeviceArray(0.00136701, dtype=float32), 0.11399999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2285, DeviceArray(0.00136464, dtype=float32), 0.11299999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2286, DeviceArray(0.00136231, dtype=float32), 0.11199999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2287, DeviceArray(0.00136002, dtype=float32), 0.11099999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2288, DeviceArray(0.00135774, dtype=float32), 0.10999999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2289, DeviceArray(0.00135551, dtype=float32), 0.10899999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2290, DeviceArray(0.00135331, dtype=float32), 0.10799999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2291, DeviceArray(0.00135114, dtype=float32), 0.10699999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2292, DeviceArray(0.001349, dtype=float32), 0.1059999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2293, DeviceArray(0.00134689, dtype=float32), 0.1049999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2294, DeviceArray(0.00134481, dtype=float32), 0.1039999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2295, DeviceArray(0.00134276, dtype=float32), 0.1029999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2296, DeviceArray(0.00134074, dtype=float32), 0.1019999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2297, DeviceArray(0.00133874, dtype=float32), 0.1009999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2298, DeviceArray(0.00133678, dtype=float32), 0.0999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2299, DeviceArray(0.00133485, dtype=float32), 0.0989999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2300, DeviceArray(0.00133294, dtype=float32), 0.0979999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2301, DeviceArray(0.00133106, dtype=float32), 0.0969999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2302, DeviceArray(0.00132921, dtype=float32), 0.0959999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2303, DeviceArray(0.00132739, dtype=float32), 0.0949999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2304, DeviceArray(0.00132559, dtype=float32), 0.0939999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2305, DeviceArray(0.00132382, dtype=float32), 0.0929999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2306, DeviceArray(0.00132207, dtype=float32), 0.0919999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2307, DeviceArray(0.00132035, dtype=float32), 0.09099999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2308, DeviceArray(0.00131866, dtype=float32), 0.08999999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2309, DeviceArray(0.00131699, dtype=float32), 0.08899999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2310, DeviceArray(0.00131535, dtype=float32), 0.08799999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2311, DeviceArray(0.00131373, dtype=float32), 0.08699999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2312, DeviceArray(0.00131214, dtype=float32), 0.08599999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2313, DeviceArray(0.00131057, dtype=float32), 0.08499999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2314, DeviceArray(0.00130902, dtype=float32), 0.08399999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2315, DeviceArray(0.0013075, dtype=float32), 0.08299999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2316, DeviceArray(0.001306, dtype=float32), 0.08199999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2317, DeviceArray(0.00130452, dtype=float32), 0.08099999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2318, DeviceArray(0.00130307, dtype=float32), 0.07999999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2319, DeviceArray(0.00130164, dtype=float32), 0.07899999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2320, DeviceArray(0.00130023, dtype=float32), 0.07799999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2321, DeviceArray(0.00129885, dtype=float32), 0.07699999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2322, DeviceArray(0.00129749, dtype=float32), 0.07599999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2323, DeviceArray(0.00129615, dtype=float32), 0.07499999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2324, DeviceArray(0.00129483, dtype=float32), 0.07399999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2325, DeviceArray(0.00129353, dtype=float32), 0.07299999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2326, DeviceArray(0.00129225, dtype=float32), 0.07199999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2327, DeviceArray(0.001291, dtype=float32), 0.07099999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2328, DeviceArray(0.00128977, dtype=float32), 0.06999999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2329, DeviceArray(0.00128855, dtype=float32), 0.06899999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2330, DeviceArray(0.00128736, dtype=float32), 0.06799999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2331, DeviceArray(0.00128619, dtype=float32), 0.06699999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2332, DeviceArray(0.00128504, dtype=float32), 0.06599999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2333, DeviceArray(0.00128391, dtype=float32), 0.06499999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2334, DeviceArray(0.0012828, dtype=float32), 0.06399999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2335, DeviceArray(0.00128171, dtype=float32), 0.06299999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2336, DeviceArray(0.00128064, dtype=float32), 0.06199999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2337, DeviceArray(0.00127958, dtype=float32), 0.060999999999998666)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2338, DeviceArray(0.00127855, dtype=float32), 0.059999999999998666)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2339, DeviceArray(0.00127754, dtype=float32), 0.058999999999998665)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2340, DeviceArray(0.00127655, dtype=float32), 0.057999999999998664)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2341, DeviceArray(0.00127557, dtype=float32), 0.05699999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2342, DeviceArray(0.00127462, dtype=float32), 0.05599999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2343, DeviceArray(0.00127368, dtype=float32), 0.05499999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2344, DeviceArray(0.00127276, dtype=float32), 0.05399999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2345, DeviceArray(0.00127186, dtype=float32), 0.05299999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2346, DeviceArray(0.00127098, dtype=float32), 0.05199999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2347, DeviceArray(0.00127012, dtype=float32), 0.05099999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2348, DeviceArray(0.00126927, dtype=float32), 0.04999999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2349, DeviceArray(0.00126845, dtype=float32), 0.048999999999998656)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2350, DeviceArray(0.00126764, dtype=float32), 0.047999999999998655)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2351, DeviceArray(0.00126685, dtype=float32), 0.046999999999998654)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2352, DeviceArray(0.00126608, dtype=float32), 0.04599999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2353, DeviceArray(0.00126532, dtype=float32), 0.04499999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2354, DeviceArray(0.00126459, dtype=float32), 0.04399999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2355, DeviceArray(0.00126387, dtype=float32), 0.04299999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2356, DeviceArray(0.00126316, dtype=float32), 0.04199999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2357, DeviceArray(0.00126248, dtype=float32), 0.04099999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2358, DeviceArray(0.00126181, dtype=float32), 0.03999999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2359, DeviceArray(0.00126116, dtype=float32), 0.03899999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2360, DeviceArray(0.00126053, dtype=float32), 0.037999999999998646)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2361, DeviceArray(0.00125991, dtype=float32), 0.036999999999998645)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2362, DeviceArray(0.00125931, dtype=float32), 0.035999999999998644)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2363, DeviceArray(0.00125873, dtype=float32), 0.03499999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2364, DeviceArray(0.00125817, dtype=float32), 0.03399999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2365, DeviceArray(0.00125762, dtype=float32), 0.03299999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2366, DeviceArray(0.00125709, dtype=float32), 0.03199999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2367, DeviceArray(0.00125657, dtype=float32), 0.03099999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2368, DeviceArray(0.00125607, dtype=float32), 0.02999999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2369, DeviceArray(0.00125559, dtype=float32), 0.028999999999998638)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2370, DeviceArray(0.00125513, dtype=float32), 0.027999999999998637)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2371, DeviceArray(0.00125468, dtype=float32), 0.026999999999998636)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2372, DeviceArray(0.00125424, dtype=float32), 0.025999999999998635)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2373, DeviceArray(0.00125383, dtype=float32), 0.024999999999998634)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2374, DeviceArray(0.00125343, dtype=float32), 0.023999999999998634)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2375, DeviceArray(0.00125305, dtype=float32), 0.022999999999998633)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2376, DeviceArray(0.00125268, dtype=float32), 0.021999999999998632)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2377, DeviceArray(0.00125233, dtype=float32), 0.02099999999999863)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2378, DeviceArray(0.00125199, dtype=float32), 0.01999999999999863)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2379, DeviceArray(0.00125167, dtype=float32), 0.01899999999999863)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2380, DeviceArray(0.00125137, dtype=float32), 0.017999999999998628)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2381, DeviceArray(0.00125108, dtype=float32), 0.016999999999998627)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2382, DeviceArray(0.00125081, dtype=float32), 0.015999999999998626)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2383, DeviceArray(0.00125056, dtype=float32), 0.014999999999998626)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2384, DeviceArray(0.00125032, dtype=float32), 0.013999999999998625)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2385, DeviceArray(0.0012501, dtype=float32), 0.012999999999998624)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2386, DeviceArray(0.00124989, dtype=float32), 0.011999999999998623)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2387, DeviceArray(0.0012497, dtype=float32), 0.010999999999998622)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2388, DeviceArray(0.00124953, dtype=float32), 0.009999999999998621)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2389, DeviceArray(0.00124937, dtype=float32), 0.00899999999999862)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2390, DeviceArray(0.00124922, dtype=float32), 0.00799999999999862)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2391, DeviceArray(0.0012491, dtype=float32), 0.006999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2392, DeviceArray(0.00124899, dtype=float32), 0.005999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2393, DeviceArray(0.00124889, dtype=float32), 0.004999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2394, DeviceArray(0.00124881, dtype=float32), 0.003999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2395, DeviceArray(0.00124875, dtype=float32), 0.0029999999999986192)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2396, DeviceArray(0.0012487, dtype=float32), 0.001999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2397, DeviceArray(0.00124867, dtype=float32), 0.0009999999999986192)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2398, DeviceArray(0.00124865, dtype=float32), -1.3808398868775384e-15)
# Loss Updated!

# %%
with open('/content/gdrive/My Drive/EX3_1.npy', 'wb') as f:
    np.save(f, bestParams)

# %%
bestParams = np.load('/content/gdrive/My Drive/EX3_1.npy', allow_pickle=True)

# %%
loss(bestParams, inputs, consts)
# Out:
# DeviceArray(0.00124865, dtype=float32)

# %%
consts['w0'] = np.load('/content/gdrive/My Drive/EX3_1.npy', allow_pickle=True)

# %%
def defect(t, c):
    vals = v_nn_V(c['w0'], t, c)
    phi = vals[:, 0]
    rho = vals[:, 1]
    L1 = vals[:, 2]
    L2 = vals[:, 3]

    tmp = v_dNNdt_V(c['w0'], t, c)
    dphi = tmp[:, 0]
    drho = tmp[:, 1]
    dL1 = tmp[:, 2]
    dL2 = tmp[:, 3]

    H0 = L2*(-c['k']*rho + c['N']*phi*(1.-0.)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - rho/c['rhoMax'] * phi*(1.-0.)*c['v'])
    H1 = L2*(-c['k']*rho + c['N']*phi*(1.-0.9)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - phi*0.9*0.9 - rho/c['rhoMax'] * phi*(1.-0.9)*c['v'])

    utest = np.clip(0.5*(-L2*c['N']*c['rhoMax'] + rho*c['v'] - c['n']*rho*c['v'] + c['n']*L1*rho*c['v'])/(c['rhoMax']*(1. - c['n']+ c['n']*L1)),0., 0.9)
    Hu = L2*(-c['k']*rho + c['N']*phi*(1-utest)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - phi*utest*utest - rho/c['rhoMax'] * phi*(1.-utest)*c['v'])

    #u = np.zeros(len(utest)) - 2.0
    u = np.where(H0 > H1, np.zeros(len(utest)), np.ones(len(utest)) - 0.1)

    H = np.where(H0 > H1, H0, H1)

    
    u = np.where(Hu >= H, utest, u)
    #u = np.where(u > Hu, u, utest)

    res0 = dphi - (-c['b']*phi + c['n']*(c['z']*phi - phi*u*u - rho/c['rhoMax'] * phi*(1.-u)*c['v']))
    res1 = drho - (-c['k']*rho + c['N']*phi*(1.-u))

    res2 = dL1 + (L2*c['N']*(1.-u) - c['b']*L1 + 
                   (1.-c['n']+c['n']*L1)*(c['z'] - u*u - rho/c['rhoMax'] * (1.-u)*c['v']))
    res3 = (dL2 + (-L2*c['k'] - 
                   (1.-c['n']+c['n']*L1)*phi*(1.-u)*c['v'])/c['rhoMax'])
    return np.array([res0, res1, res2, res3])

# %%
def loss2(params, t, c):
    vals = v_nn_V(params, t, c)
    phi = vals[:, 0]
    rho = vals[:, 1]
    L1 = vals[:, 2]
    L2 = vals[:, 3]

    tmp = v_dNNdt_V(params, t, c)
    dphi = tmp[:, 0]
    drho = tmp[:, 1]
    dL1 = tmp[:, 2]
    dL2 = tmp[:, 3]

    H0 = L2*(-c['k']*rho + c['N']*phi*(1.-0.)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - rho/c['rhoMax'] * phi*(1.-0.)*c['v'])
    H1 = L2*(-c['k']*rho + c['N']*phi*(1.-0.9)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - phi*0.9*0.9 - rho/c['rhoMax'] * phi*(1.-0.9)*c['v'])

    utest = np.clip(0.5*(-L2*c['N']*c['rhoMax'] + rho*c['v'] - c['n']*rho*c['v'] + c['n']*L1*rho*c['v'])/(c['rhoMax']*(1. - c['n']+ c['n']*L1)),0., 0.9)
    Hu = L2*(-c['k']*rho + c['N']*phi*(1-utest)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - phi*utest*utest - rho/c['rhoMax'] * phi*(1.-utest)*c['v'])

    #u = np.zeros(len(utest)) - 2.0
    u = np.where(H0 > H1, np.zeros(len(utest)), np.ones(len(utest)) - 0.1)

    H = np.where(H0 > H1, H0, H1)

    
    u = np.where(Hu >= H, utest, u)
    #u = np.where(u > Hu, u, utest)
    d = defect(t, c)
    res = 0.
    res += (dphi - (-c['b']*phi + c['n']*(c['z']*phi - phi*u*u - rho/c['rhoMax'] * phi*(1.-u)*c['v']) + d[0]))**2
    res += (drho - (-c['k']*rho + c['N']*phi*(1.-u) + d[1]))**2

    res += (dL1 - (-(L2*c['N']*(1.-u) - c['b']*L1 + 
                   (1.-c['n']+c['n']*L1)*(c['z'] - u*u - rho/c['rhoMax'] * (1.-u)*c['v'])) + d[2]))**2
    res += (dL2 - (-(-L2*c['k'] - 
                   ((1.-c['n']+c['n']*L1)*phi*(1.-u)*c['v'])/c['rhoMax']) + d[3]))**2
    
    return res.mean()

dLoss2 = grad(loss2, 0)

# %%
epochs = 2500

learning_rate = 0.01
#inputs = np.linspace(np.array([0., 1e-4]), np.array([consts['t1']-1e-4, consts['ics'][0]]), num=501)
batch_size = 500
key = random.PRNGKey(0)
M0 = consts['M0']
M1 = consts['M1']
M2 = consts['M2']
params = (random.normal(key, shape=(2*M0 + M0*M1 + M1 + M1*M2+M2+4*M2+4, )))*0.1
#params = params - params.min()
#params /= params.max()
v = 0.0
m = 0.0
b1 = 0.9
b2 = 0.999
bestLoss = 1000000.0
bestParams2 = params
ec = 1

# %%
bad_ep = 0
step = -1e-4
k = 0
PastParams = params
max_lr=0.2
for epoch in range(epochs):
    i = numpy.random.randint(0, inputs.shape[0], size=batch_size)
    #sample = inputs[i]
    sample = inputs
    #rnd = (numpy.random.random(batch_size)-0.5 )*0.1
    #rnd = numpy.clip(rnd, -0.0005, 0.0005)
    #sample += rnd
    #sample = numpy.clip(sample, consts['t0'], consts['t1'] - 1e-4)
    #assert numpy.array(sample).min() >=0 and numpy.array(sample).max() <= 1.
    #print(sample)
    #learning_rate = learning_rate * 0.999
    learning_rate = learning_rate + step
    #if bad_ep >= 50:
      #k = 250
      #learning_rate = learning_rate + step
      #bad_ep = 0
    if learning_rate <= 1e-8:
      step= 1e-2
      #PastParams = PastParams + 0.75*(params - PastParams)
      #k = 0
      #params = PastParams
      #v = 0.0
      #m = 0.0

    if learning_rate >= max_lr:
      step = -1e-3
    if epoch % ec == 0:
      currLoss = loss2(params, inputs, consts)
      #print('epoch: %3d loss: %.6f lr: %.6f', (epoch, currLoss, learning_rate) )
      if currLoss < bestLoss:
        print('epoch: %3d loss: %.6f lr: %.6f', (epoch, currLoss, learning_rate) )
        print('Loss Updated!')
        print(' ')
        bestParams2 = params
        bestLoss = currLoss
        bad_ep = 0
      else:
        bad_ep += 1
      #  if bad_ep >= 50:
      #    learning_rate = learning_rate * 0.1
      #    if learning_rate <= 1e-5:
      #      break

         # bad_ep=0

    gradient = dLoss2(params, sample, consts)# + momentum*velocity
    m = b1*m + (1. -b1)* gradient
    v = b2*v + (1.-b2)*(np.square(gradient))
    m0 = m / (1. -b1)
    v0 = v / (1. -b2)
    velocity = - learning_rate*(m0 / (np.sqrt(v0) + 1e-8))##*gradient#
    params += velocity

    k += 1
    if k == 200:
      PastParams = PastParams + 0.5*(params - PastParams)
      k = 0
      params = PastParams
      #max_lr = max(0.99*max_lr, 0.1)
# Out:
# epoch: %3d loss: %.6f lr: %.6f (0, DeviceArray(2.091759, dtype=float32), 0.0099)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (1, DeviceArray(0.34589577, dtype=float32), 0.009800000000000001)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (6, DeviceArray(0.27788708, dtype=float32), 0.009300000000000004)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (10, DeviceArray(0.08655353, dtype=float32), 0.008900000000000007)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (19, DeviceArray(0.08134246, dtype=float32), 0.008000000000000012)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (20, DeviceArray(0.07800846, dtype=float32), 0.007900000000000013)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (27, DeviceArray(0.07066466, dtype=float32), 0.007200000000000011)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (28, DeviceArray(0.05684417, dtype=float32), 0.007100000000000011)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (29, DeviceArray(0.05338066, dtype=float32), 0.0070000000000000106)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (37, DeviceArray(0.05137746, dtype=float32), 0.0062000000000000085)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (38, DeviceArray(0.04925379, dtype=float32), 0.006100000000000008)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (39, DeviceArray(0.04862818, dtype=float32), 0.006000000000000008)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (40, DeviceArray(0.04860635, dtype=float32), 0.005900000000000008)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (41, DeviceArray(0.04854794, dtype=float32), 0.005800000000000007)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (42, DeviceArray(0.04847779, dtype=float32), 0.005700000000000007)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (48, DeviceArray(0.04816951, dtype=float32), 0.005100000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (49, DeviceArray(0.04653724, dtype=float32), 0.005000000000000005)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (50, DeviceArray(0.04519146, dtype=float32), 0.004900000000000005)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (51, DeviceArray(0.04443255, dtype=float32), 0.004800000000000005)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (52, DeviceArray(0.04428178, dtype=float32), 0.0047000000000000045)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (63, DeviceArray(0.04421282, dtype=float32), 0.0036000000000000034)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (64, DeviceArray(0.04416603, dtype=float32), 0.0035000000000000035)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (65, DeviceArray(0.0441286, dtype=float32), 0.0034000000000000037)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (66, DeviceArray(0.04409231, dtype=float32), 0.003300000000000004)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (67, DeviceArray(0.04405839, dtype=float32), 0.003200000000000004)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (68, DeviceArray(0.04403286, dtype=float32), 0.0031000000000000042)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (69, DeviceArray(0.04402111, dtype=float32), 0.0030000000000000044)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (77, DeviceArray(0.04401276, dtype=float32), 0.0022000000000000058)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (78, DeviceArray(0.04397701, dtype=float32), 0.002100000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (79, DeviceArray(0.04394124, dtype=float32), 0.002000000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (80, DeviceArray(0.04390907, dtype=float32), 0.001900000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (81, DeviceArray(0.04388275, dtype=float32), 0.001800000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (82, DeviceArray(0.04386312, dtype=float32), 0.001700000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (83, DeviceArray(0.04384985, dtype=float32), 0.001600000000000006)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (84, DeviceArray(0.04384192, dtype=float32), 0.0015000000000000059)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (85, DeviceArray(0.04383798, dtype=float32), 0.0014000000000000058)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (86, DeviceArray(0.04383668, dtype=float32), 0.0013000000000000058)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (101, DeviceArray(0.04383183, dtype=float32), 0.020000000000000004)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (163, DeviceArray(0.04382647, dtype=float32), 0.156)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (164, DeviceArray(0.04343978, dtype=float32), 0.155)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (173, DeviceArray(0.04322721, dtype=float32), 0.146)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (174, DeviceArray(0.04313774, dtype=float32), 0.145)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (177, DeviceArray(0.04311397, dtype=float32), 0.142)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (178, DeviceArray(0.04298378, dtype=float32), 0.141)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (179, DeviceArray(0.04292496, dtype=float32), 0.13999999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (181, DeviceArray(0.04291782, dtype=float32), 0.13799999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (182, DeviceArray(0.0428435, dtype=float32), 0.13699999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (183, DeviceArray(0.04275226, dtype=float32), 0.13599999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (184, DeviceArray(0.04270082, dtype=float32), 0.13499999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (185, DeviceArray(0.04268748, dtype=float32), 0.13399999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (186, DeviceArray(0.04266587, dtype=float32), 0.13299999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (187, DeviceArray(0.0426068, dtype=float32), 0.13199999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (188, DeviceArray(0.0425271, dtype=float32), 0.13099999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (189, DeviceArray(0.04246133, dtype=float32), 0.12999999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (190, DeviceArray(0.04242032, dtype=float32), 0.12899999999999998)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (191, DeviceArray(0.04238439, dtype=float32), 0.12799999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (192, DeviceArray(0.04233144, dtype=float32), 0.12699999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (193, DeviceArray(0.04226159, dtype=float32), 0.12599999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (194, DeviceArray(0.04219216, dtype=float32), 0.12499999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (195, DeviceArray(0.04213546, dtype=float32), 0.12399999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (196, DeviceArray(0.04208736, dtype=float32), 0.12299999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (197, DeviceArray(0.04203587, dtype=float32), 0.12199999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (198, DeviceArray(0.04197562, dtype=float32), 0.12099999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (199, DeviceArray(0.04191177, dtype=float32), 0.11999999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (200, DeviceArray(0.04129408, dtype=float32), 0.11899999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (201, DeviceArray(0.04101661, dtype=float32), 0.11799999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (202, DeviceArray(0.04068308, dtype=float32), 0.11699999999999997)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (203, DeviceArray(0.04049483, dtype=float32), 0.11599999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (204, DeviceArray(0.0403324, dtype=float32), 0.11499999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (205, DeviceArray(0.04003887, dtype=float32), 0.11399999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (206, DeviceArray(0.03969384, dtype=float32), 0.11299999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (207, DeviceArray(0.03944086, dtype=float32), 0.11199999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (208, DeviceArray(0.03924318, dtype=float32), 0.11099999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (209, DeviceArray(0.03897794, dtype=float32), 0.10999999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (210, DeviceArray(0.03864964, dtype=float32), 0.10899999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (211, DeviceArray(0.03835265, dtype=float32), 0.10799999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (212, DeviceArray(0.03809692, dtype=float32), 0.10699999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (213, DeviceArray(0.03780586, dtype=float32), 0.10599999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (214, DeviceArray(0.03745098, dtype=float32), 0.10499999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (215, DeviceArray(0.03708421, dtype=float32), 0.10399999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (216, DeviceArray(0.03674147, dtype=float32), 0.10299999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (217, DeviceArray(0.03639295, dtype=float32), 0.10199999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (218, DeviceArray(0.03600563, dtype=float32), 0.10099999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (219, DeviceArray(0.0355973, dtype=float32), 0.09999999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (220, DeviceArray(0.03520135, dtype=float32), 0.09899999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (221, DeviceArray(0.03481555, dtype=float32), 0.09799999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (222, DeviceArray(0.03441514, dtype=float32), 0.09699999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (223, DeviceArray(0.0339958, dtype=float32), 0.09599999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (224, DeviceArray(0.03357696, dtype=float32), 0.09499999999999995)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (225, DeviceArray(0.03316968, dtype=float32), 0.09399999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (226, DeviceArray(0.03276322, dtype=float32), 0.09299999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (227, DeviceArray(0.0323456, dtype=float32), 0.09199999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (228, DeviceArray(0.03192142, dtype=float32), 0.09099999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (229, DeviceArray(0.03150247, dtype=float32), 0.08999999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (230, DeviceArray(0.03109066, dtype=float32), 0.08899999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (231, DeviceArray(0.03067899, dtype=float32), 0.08799999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (232, DeviceArray(0.0302648, dtype=float32), 0.08699999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (233, DeviceArray(0.02985409, dtype=float32), 0.08599999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (234, DeviceArray(0.02945272, dtype=float32), 0.08499999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (235, DeviceArray(0.02905939, dtype=float32), 0.08399999999999994)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (236, DeviceArray(0.02866958, dtype=float32), 0.08299999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (237, DeviceArray(0.02828291, dtype=float32), 0.08199999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (238, DeviceArray(0.02790334, dtype=float32), 0.08099999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (239, DeviceArray(0.02753348, dtype=float32), 0.07999999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (240, DeviceArray(0.02717183, dtype=float32), 0.07899999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (241, DeviceArray(0.02681569, dtype=float32), 0.07799999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (242, DeviceArray(0.02646484, dtype=float32), 0.07699999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (243, DeviceArray(0.02612086, dtype=float32), 0.07599999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (244, DeviceArray(0.02578419, dtype=float32), 0.07499999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (245, DeviceArray(0.02545321, dtype=float32), 0.07399999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (246, DeviceArray(0.02512625, dtype=float32), 0.07299999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (247, DeviceArray(0.02480331, dtype=float32), 0.07199999999999993)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (248, DeviceArray(0.02448535, dtype=float32), 0.07099999999999992)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (249, DeviceArray(0.02417264, dtype=float32), 0.06999999999999992)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (250, DeviceArray(0.02386429, dtype=float32), 0.06899999999999992)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (251, DeviceArray(0.02355938, dtype=float32), 0.06799999999999992)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (252, DeviceArray(0.02325785, dtype=float32), 0.06699999999999992)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (253, DeviceArray(0.02296016, dtype=float32), 0.06599999999999992)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (254, DeviceArray(0.02266642, dtype=float32), 0.06499999999999992)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (255, DeviceArray(0.02237617, dtype=float32), 0.06399999999999992)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (256, DeviceArray(0.02208884, dtype=float32), 0.06299999999999992)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (257, DeviceArray(0.02180434, dtype=float32), 0.061999999999999916)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (258, DeviceArray(0.02152291, dtype=float32), 0.060999999999999915)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (259, DeviceArray(0.0212447, dtype=float32), 0.059999999999999915)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (260, DeviceArray(0.02096957, dtype=float32), 0.058999999999999914)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (261, DeviceArray(0.02069729, dtype=float32), 0.05799999999999991)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (262, DeviceArray(0.02042786, dtype=float32), 0.05699999999999991)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (263, DeviceArray(0.02016152, dtype=float32), 0.05599999999999991)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (264, DeviceArray(0.01989851, dtype=float32), 0.05499999999999991)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (265, DeviceArray(0.01963894, dtype=float32), 0.05399999999999991)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (266, DeviceArray(0.01938286, dtype=float32), 0.05299999999999991)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (267, DeviceArray(0.01913038, dtype=float32), 0.05199999999999991)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (268, DeviceArray(0.0188817, dtype=float32), 0.050999999999999907)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (269, DeviceArray(0.0186371, dtype=float32), 0.049999999999999906)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (270, DeviceArray(0.01839682, dtype=float32), 0.048999999999999905)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (271, DeviceArray(0.018161, dtype=float32), 0.047999999999999904)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (272, DeviceArray(0.01792974, dtype=float32), 0.0469999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (273, DeviceArray(0.0177032, dtype=float32), 0.0459999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (274, DeviceArray(0.01748155, dtype=float32), 0.0449999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (275, DeviceArray(0.01726495, dtype=float32), 0.0439999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (276, DeviceArray(0.01705354, dtype=float32), 0.0429999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (277, DeviceArray(0.01684741, dtype=float32), 0.0419999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (278, DeviceArray(0.01664661, dtype=float32), 0.0409999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (279, DeviceArray(0.01645123, dtype=float32), 0.0399999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (280, DeviceArray(0.01626134, dtype=float32), 0.038999999999999896)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (281, DeviceArray(0.01607701, dtype=float32), 0.037999999999999895)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (282, DeviceArray(0.01589829, dtype=float32), 0.036999999999999894)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (283, DeviceArray(0.01572518, dtype=float32), 0.03599999999999989)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (284, DeviceArray(0.01555768, dtype=float32), 0.03499999999999989)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (285, DeviceArray(0.01539579, dtype=float32), 0.03399999999999989)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (286, DeviceArray(0.01523951, dtype=float32), 0.03299999999999989)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (287, DeviceArray(0.01508881, dtype=float32), 0.03199999999999989)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (288, DeviceArray(0.01494367, dtype=float32), 0.03099999999999989)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (289, DeviceArray(0.01480404, dtype=float32), 0.029999999999999888)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (290, DeviceArray(0.01466988, dtype=float32), 0.028999999999999887)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (291, DeviceArray(0.01454112, dtype=float32), 0.027999999999999886)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (292, DeviceArray(0.0144177, dtype=float32), 0.026999999999999885)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (293, DeviceArray(0.01429956, dtype=float32), 0.025999999999999884)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (294, DeviceArray(0.01418664, dtype=float32), 0.024999999999999883)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (295, DeviceArray(0.01407886, dtype=float32), 0.023999999999999883)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (296, DeviceArray(0.01397616, dtype=float32), 0.02299999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (297, DeviceArray(0.01387845, dtype=float32), 0.02199999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (298, DeviceArray(0.01378566, dtype=float32), 0.02099999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (299, DeviceArray(0.01369771, dtype=float32), 0.01999999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (300, DeviceArray(0.01361454, dtype=float32), 0.018999999999999878)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (301, DeviceArray(0.01353606, dtype=float32), 0.017999999999999877)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (302, DeviceArray(0.0134622, dtype=float32), 0.016999999999999876)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (303, DeviceArray(0.01339289, dtype=float32), 0.015999999999999875)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (304, DeviceArray(0.01332807, dtype=float32), 0.014999999999999875)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (305, DeviceArray(0.01326766, dtype=float32), 0.013999999999999874)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (306, DeviceArray(0.01321161, dtype=float32), 0.012999999999999873)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (307, DeviceArray(0.01315984, dtype=float32), 0.011999999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (308, DeviceArray(0.0131123, dtype=float32), 0.010999999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (309, DeviceArray(0.01306895, dtype=float32), 0.00999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (310, DeviceArray(0.01302971, dtype=float32), 0.00899999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (311, DeviceArray(0.01299455, dtype=float32), 0.007999999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (312, DeviceArray(0.01296342, dtype=float32), 0.006999999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (313, DeviceArray(0.01293629, dtype=float32), 0.005999999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (314, DeviceArray(0.0129131, dtype=float32), 0.004999999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (315, DeviceArray(0.01289385, dtype=float32), 0.003999999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (316, DeviceArray(0.01287848, dtype=float32), 0.0029999999999998682)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (317, DeviceArray(0.01286698, dtype=float32), 0.001999999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (318, DeviceArray(0.01285933, dtype=float32), 0.0009999999999998682)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (319, DeviceArray(0.01285551, dtype=float32), -1.3183898417423734e-16)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (321, DeviceArray(0.01281744, dtype=float32), 0.01999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (322, DeviceArray(0.01274162, dtype=float32), 0.029999999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (323, DeviceArray(0.01262863, dtype=float32), 0.03999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (324, DeviceArray(0.01247936, dtype=float32), 0.04999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (325, DeviceArray(0.01229505, dtype=float32), 0.05999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (326, DeviceArray(0.01207736, dtype=float32), 0.06999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (327, DeviceArray(0.01182839, dtype=float32), 0.07999999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (328, DeviceArray(0.01155073, dtype=float32), 0.08999999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (329, DeviceArray(0.01124746, dtype=float32), 0.09999999999999985)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (330, DeviceArray(0.01092217, dtype=float32), 0.10999999999999985)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (331, DeviceArray(0.01057891, dtype=float32), 0.11999999999999984)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (332, DeviceArray(0.01022218, dtype=float32), 0.12999999999999984)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (333, DeviceArray(0.00985679, dtype=float32), 0.13999999999999985)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (334, DeviceArray(0.00948772, dtype=float32), 0.14999999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (335, DeviceArray(0.00911983, dtype=float32), 0.15999999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (336, DeviceArray(0.00875767, dtype=float32), 0.16999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (337, DeviceArray(0.00840532, dtype=float32), 0.17999999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (338, DeviceArray(0.00806629, dtype=float32), 0.1899999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (339, DeviceArray(0.00774356, dtype=float32), 0.1999999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (340, DeviceArray(0.00743955, dtype=float32), 0.2099999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (341, DeviceArray(0.00715619, dtype=float32), 0.2089999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (342, DeviceArray(0.00690691, dtype=float32), 0.2079999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (343, DeviceArray(0.00668708, dtype=float32), 0.2069999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (344, DeviceArray(0.00649186, dtype=float32), 0.2059999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (345, DeviceArray(0.00631622, dtype=float32), 0.2049999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (346, DeviceArray(0.00615514, dtype=float32), 0.2039999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (347, DeviceArray(0.00600389, dtype=float32), 0.2029999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (348, DeviceArray(0.00585827, dtype=float32), 0.2019999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (349, DeviceArray(0.00571489, dtype=float32), 0.2009999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (350, DeviceArray(0.0055714, dtype=float32), 0.1999999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (351, DeviceArray(0.00542657, dtype=float32), 0.1989999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (352, DeviceArray(0.00528029, dtype=float32), 0.1979999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (353, DeviceArray(0.00513349, dtype=float32), 0.1969999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (354, DeviceArray(0.00498795, dtype=float32), 0.1959999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (355, DeviceArray(0.00484604, dtype=float32), 0.1949999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (356, DeviceArray(0.00471047, dtype=float32), 0.1939999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (357, DeviceArray(0.00458383, dtype=float32), 0.1929999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (358, DeviceArray(0.00446837, dtype=float32), 0.1919999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (359, DeviceArray(0.00436564, dtype=float32), 0.1909999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (360, DeviceArray(0.0042763, dtype=float32), 0.1899999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (361, DeviceArray(0.00420005, dtype=float32), 0.1889999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (362, DeviceArray(0.00413573, dtype=float32), 0.1879999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (363, DeviceArray(0.00408149, dtype=float32), 0.1869999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (364, DeviceArray(0.00403501, dtype=float32), 0.1859999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (365, DeviceArray(0.00399384, dtype=float32), 0.1849999999999999)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (366, DeviceArray(0.00395572, dtype=float32), 0.18399999999999989)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (367, DeviceArray(0.00391873, dtype=float32), 0.18299999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (368, DeviceArray(0.00388149, dtype=float32), 0.18199999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (369, DeviceArray(0.00384323, dtype=float32), 0.18099999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (370, DeviceArray(0.0038037, dtype=float32), 0.17999999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (371, DeviceArray(0.00376314, dtype=float32), 0.17899999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (372, DeviceArray(0.0037221, dtype=float32), 0.17799999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (373, DeviceArray(0.00368126, dtype=float32), 0.17699999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (374, DeviceArray(0.00364129, dtype=float32), 0.17599999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (375, DeviceArray(0.00360274, dtype=float32), 0.17499999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (376, DeviceArray(0.00356595, dtype=float32), 0.17399999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (377, DeviceArray(0.00353107, dtype=float32), 0.17299999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (378, DeviceArray(0.00349804, dtype=float32), 0.17199999999999988)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (379, DeviceArray(0.0034667, dtype=float32), 0.17099999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (380, DeviceArray(0.00343675, dtype=float32), 0.16999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (381, DeviceArray(0.00340791, dtype=float32), 0.16899999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (382, DeviceArray(0.00337988, dtype=float32), 0.16799999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (383, DeviceArray(0.00335239, dtype=float32), 0.16699999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (384, DeviceArray(0.00332525, dtype=float32), 0.16599999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (385, DeviceArray(0.00329829, dtype=float32), 0.16499999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (386, DeviceArray(0.00327144, dtype=float32), 0.16399999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (387, DeviceArray(0.00324463, dtype=float32), 0.16299999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (388, DeviceArray(0.00321787, dtype=float32), 0.16199999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (389, DeviceArray(0.00319116, dtype=float32), 0.16099999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (390, DeviceArray(0.00316453, dtype=float32), 0.15999999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (391, DeviceArray(0.00313802, dtype=float32), 0.15899999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (392, DeviceArray(0.00311165, dtype=float32), 0.15799999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (393, DeviceArray(0.00308546, dtype=float32), 0.15699999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (394, DeviceArray(0.00305947, dtype=float32), 0.15599999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (395, DeviceArray(0.00303367, dtype=float32), 0.15499999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (396, DeviceArray(0.00300805, dtype=float32), 0.15399999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (397, DeviceArray(0.00298259, dtype=float32), 0.15299999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (398, DeviceArray(0.00295725, dtype=float32), 0.15199999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (399, DeviceArray(0.00293198, dtype=float32), 0.15099999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (567, DeviceArray(0.00293122, dtype=float32), 0.16999999999999973)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (568, DeviceArray(0.00289972, dtype=float32), 0.17999999999999974)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (569, DeviceArray(0.00286649, dtype=float32), 0.18999999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (570, DeviceArray(0.00283154, dtype=float32), 0.19999999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (571, DeviceArray(0.00279487, dtype=float32), 0.20999999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (572, DeviceArray(0.00275648, dtype=float32), 0.20899999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (573, DeviceArray(0.00271838, dtype=float32), 0.20799999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (574, DeviceArray(0.00268052, dtype=float32), 0.20699999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (575, DeviceArray(0.0026429, dtype=float32), 0.20599999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (576, DeviceArray(0.00260547, dtype=float32), 0.20499999999999977)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (577, DeviceArray(0.00256823, dtype=float32), 0.20399999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (578, DeviceArray(0.00253115, dtype=float32), 0.20299999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (579, DeviceArray(0.00249421, dtype=float32), 0.20199999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (580, DeviceArray(0.00245741, dtype=float32), 0.20099999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (581, DeviceArray(0.00242072, dtype=float32), 0.19999999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (582, DeviceArray(0.00238414, dtype=float32), 0.19899999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (583, DeviceArray(0.00234767, dtype=float32), 0.19799999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (584, DeviceArray(0.0023113, dtype=float32), 0.19699999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (585, DeviceArray(0.00227504, dtype=float32), 0.19599999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (586, DeviceArray(0.00223888, dtype=float32), 0.19499999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (587, DeviceArray(0.00220282, dtype=float32), 0.19399999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (588, DeviceArray(0.00216688, dtype=float32), 0.19299999999999976)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (589, DeviceArray(0.00213105, dtype=float32), 0.19199999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (590, DeviceArray(0.00209534, dtype=float32), 0.19099999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (591, DeviceArray(0.00205976, dtype=float32), 0.18999999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (592, DeviceArray(0.00202431, dtype=float32), 0.18899999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (593, DeviceArray(0.001989, dtype=float32), 0.18799999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (594, DeviceArray(0.00195385, dtype=float32), 0.18699999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (595, DeviceArray(0.00191885, dtype=float32), 0.18599999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (596, DeviceArray(0.00188404, dtype=float32), 0.18499999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (597, DeviceArray(0.0018494, dtype=float32), 0.18399999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (598, DeviceArray(0.00181497, dtype=float32), 0.18299999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (599, DeviceArray(0.00178074, dtype=float32), 0.18199999999999975)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (665, DeviceArray(0.00176376, dtype=float32), 0.11599999999999969)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (666, DeviceArray(0.00173633, dtype=float32), 0.11499999999999969)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (667, DeviceArray(0.00171285, dtype=float32), 0.11399999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (668, DeviceArray(0.00167753, dtype=float32), 0.11299999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (669, DeviceArray(0.00165292, dtype=float32), 0.11199999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (670, DeviceArray(0.00162472, dtype=float32), 0.11099999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (671, DeviceArray(0.00159391, dtype=float32), 0.10999999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (672, DeviceArray(0.00157176, dtype=float32), 0.10899999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (673, DeviceArray(0.00154263, dtype=float32), 0.10799999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (674, DeviceArray(0.00151392, dtype=float32), 0.10699999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (675, DeviceArray(0.00149269, dtype=float32), 0.10599999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (676, DeviceArray(0.00146516, dtype=float32), 0.10499999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (677, DeviceArray(0.00143814, dtype=float32), 0.10399999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (678, DeviceArray(0.00141645, dtype=float32), 0.10299999999999968)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (679, DeviceArray(0.00139086, dtype=float32), 0.10199999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (680, DeviceArray(0.00136591, dtype=float32), 0.10099999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (681, DeviceArray(0.00134404, dtype=float32), 0.09999999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (682, DeviceArray(0.00131987, dtype=float32), 0.09899999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (683, DeviceArray(0.00129681, dtype=float32), 0.09799999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (684, DeviceArray(0.0012756, dtype=float32), 0.09699999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (685, DeviceArray(0.00125272, dtype=float32), 0.09599999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (686, DeviceArray(0.00123105, dtype=float32), 0.09499999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (687, DeviceArray(0.00121088, dtype=float32), 0.09399999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (688, DeviceArray(0.00118941, dtype=float32), 0.09299999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (689, DeviceArray(0.00116881, dtype=float32), 0.09199999999999967)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (690, DeviceArray(0.00114962, dtype=float32), 0.09099999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (691, DeviceArray(0.00112966, dtype=float32), 0.08999999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (692, DeviceArray(0.00111016, dtype=float32), 0.08899999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (693, DeviceArray(0.00109194, dtype=float32), 0.08799999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (694, DeviceArray(0.00107341, dtype=float32), 0.08699999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (695, DeviceArray(0.00105507, dtype=float32), 0.08599999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (696, DeviceArray(0.00103772, dtype=float32), 0.08499999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (697, DeviceArray(0.00102047, dtype=float32), 0.08399999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (698, DeviceArray(0.00100332, dtype=float32), 0.08299999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (699, DeviceArray(0.0009869, dtype=float32), 0.08199999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (700, DeviceArray(0.00097074, dtype=float32), 0.08099999999999966)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (701, DeviceArray(0.00095475, dtype=float32), 0.07999999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (702, DeviceArray(0.00093934, dtype=float32), 0.07899999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (703, DeviceArray(0.00092424, dtype=float32), 0.07799999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (704, DeviceArray(0.00090931, dtype=float32), 0.07699999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (705, DeviceArray(0.00089487, dtype=float32), 0.07599999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (706, DeviceArray(0.00088084, dtype=float32), 0.07499999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (707, DeviceArray(0.00086694, dtype=float32), 0.07399999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (708, DeviceArray(0.00085338, dtype=float32), 0.07299999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (709, DeviceArray(0.0008403, dtype=float32), 0.07199999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (710, DeviceArray(0.00082744, dtype=float32), 0.07099999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (711, DeviceArray(0.00081482, dtype=float32), 0.06999999999999965)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (712, DeviceArray(0.0008026, dtype=float32), 0.06899999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (713, DeviceArray(0.0007907, dtype=float32), 0.06799999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (714, DeviceArray(0.00077902, dtype=float32), 0.06699999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (715, DeviceArray(0.00076765, dtype=float32), 0.06599999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (716, DeviceArray(0.00075661, dtype=float32), 0.06499999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (717, DeviceArray(0.00074582, dtype=float32), 0.06399999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (718, DeviceArray(0.00073529, dtype=float32), 0.06299999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (719, DeviceArray(0.00072507, dtype=float32), 0.06199999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (720, DeviceArray(0.00071512, dtype=float32), 0.06099999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (721, DeviceArray(0.00070541, dtype=float32), 0.05999999999999964)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (722, DeviceArray(0.00069596, dtype=float32), 0.058999999999999636)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (723, DeviceArray(0.00068678, dtype=float32), 0.057999999999999635)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (724, DeviceArray(0.00067785, dtype=float32), 0.056999999999999634)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (725, DeviceArray(0.00066915, dtype=float32), 0.05599999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (726, DeviceArray(0.0006607, dtype=float32), 0.05499999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (727, DeviceArray(0.0006525, dtype=float32), 0.05399999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (728, DeviceArray(0.00064451, dtype=float32), 0.05299999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (729, DeviceArray(0.00063675, dtype=float32), 0.05199999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (730, DeviceArray(0.00062922, dtype=float32), 0.05099999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (731, DeviceArray(0.00062191, dtype=float32), 0.04999999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (732, DeviceArray(0.00061481, dtype=float32), 0.04899999999999963)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (733, DeviceArray(0.00060792, dtype=float32), 0.047999999999999626)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (734, DeviceArray(0.00060123, dtype=float32), 0.046999999999999625)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (735, DeviceArray(0.00059475, dtype=float32), 0.045999999999999625)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (736, DeviceArray(0.00058847, dtype=float32), 0.044999999999999624)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (737, DeviceArray(0.00058238, dtype=float32), 0.04399999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (738, DeviceArray(0.00057648, dtype=float32), 0.04299999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (739, DeviceArray(0.00057077, dtype=float32), 0.04199999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (740, DeviceArray(0.00056524, dtype=float32), 0.04099999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (741, DeviceArray(0.00055989, dtype=float32), 0.03999999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (742, DeviceArray(0.00055471, dtype=float32), 0.03899999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (743, DeviceArray(0.00054971, dtype=float32), 0.03799999999999962)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (744, DeviceArray(0.00054488, dtype=float32), 0.036999999999999617)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (745, DeviceArray(0.00054021, dtype=float32), 0.035999999999999616)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (746, DeviceArray(0.00053571, dtype=float32), 0.034999999999999615)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (747, DeviceArray(0.00053137, dtype=float32), 0.033999999999999614)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (748, DeviceArray(0.00052718, dtype=float32), 0.03299999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (749, DeviceArray(0.00052315, dtype=float32), 0.03199999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (750, DeviceArray(0.00051927, dtype=float32), 0.03099999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (751, DeviceArray(0.00051554, dtype=float32), 0.02999999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (752, DeviceArray(0.00051195, dtype=float32), 0.02899999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (753, DeviceArray(0.00050851, dtype=float32), 0.02799999999999961)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (754, DeviceArray(0.00050521, dtype=float32), 0.026999999999999608)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (755, DeviceArray(0.00050205, dtype=float32), 0.025999999999999607)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (756, DeviceArray(0.00049902, dtype=float32), 0.024999999999999606)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (757, DeviceArray(0.00049613, dtype=float32), 0.023999999999999605)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (758, DeviceArray(0.00049337, dtype=float32), 0.022999999999999604)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (759, DeviceArray(0.00049074, dtype=float32), 0.021999999999999603)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (760, DeviceArray(0.00048824, dtype=float32), 0.020999999999999602)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (761, DeviceArray(0.00048587, dtype=float32), 0.0199999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (762, DeviceArray(0.00048362, dtype=float32), 0.0189999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (763, DeviceArray(0.0004815, dtype=float32), 0.0179999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (764, DeviceArray(0.00047949, dtype=float32), 0.0169999999999996)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (765, DeviceArray(0.00047761, dtype=float32), 0.015999999999999598)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (766, DeviceArray(0.00047584, dtype=float32), 0.014999999999999597)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (767, DeviceArray(0.0004742, dtype=float32), 0.013999999999999596)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (768, DeviceArray(0.00047266, dtype=float32), 0.012999999999999595)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (769, DeviceArray(0.00047125, dtype=float32), 0.011999999999999594)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (770, DeviceArray(0.00046994, dtype=float32), 0.010999999999999593)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (771, DeviceArray(0.00046875, dtype=float32), 0.009999999999999593)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (772, DeviceArray(0.00046767, dtype=float32), 0.008999999999999592)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (773, DeviceArray(0.0004667, dtype=float32), 0.00799999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (774, DeviceArray(0.00046584, dtype=float32), 0.006999999999999591)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (775, DeviceArray(0.00046509, dtype=float32), 0.005999999999999591)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (776, DeviceArray(0.00046445, dtype=float32), 0.004999999999999591)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (777, DeviceArray(0.00046392, dtype=float32), 0.003999999999999591)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (778, DeviceArray(0.00046349, dtype=float32), 0.0029999999999995907)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (779, DeviceArray(0.00046317, dtype=float32), 0.0019999999999995906)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (780, DeviceArray(0.00046296, dtype=float32), 0.0009999999999995906)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (781, DeviceArray(0.00046285, dtype=float32), -4.0939474033052647e-16)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (783, DeviceArray(0.00046179, dtype=float32), 0.01999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (784, DeviceArray(0.00045968, dtype=float32), 0.02999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (785, DeviceArray(0.00045652, dtype=float32), 0.03999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (786, DeviceArray(0.00045233, dtype=float32), 0.04999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (787, DeviceArray(0.00044713, dtype=float32), 0.059999999999999595)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (788, DeviceArray(0.00044094, dtype=float32), 0.06999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (789, DeviceArray(0.00043379, dtype=float32), 0.07999999999999959)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (790, DeviceArray(0.00042572, dtype=float32), 0.08999999999999958)
# Loss Updated!
#
# ...
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2282, DeviceArray(1.8110659e-05, dtype=float32), 0.11599999999999872)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2283, DeviceArray(1.8073451e-05, dtype=float32), 0.11499999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2284, DeviceArray(1.7932249e-05, dtype=float32), 0.11399999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2285, DeviceArray(1.7883376e-05, dtype=float32), 0.11299999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2286, DeviceArray(1.7761637e-05, dtype=float32), 0.11199999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2287, DeviceArray(1.7703678e-05, dtype=float32), 0.11099999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2288, DeviceArray(1.7592687e-05, dtype=float32), 0.10999999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2289, DeviceArray(1.753404e-05, dtype=float32), 0.10899999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2290, DeviceArray(1.7429826e-05, dtype=float32), 0.10799999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2291, DeviceArray(1.7369157e-05, dtype=float32), 0.10699999999999871)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2292, DeviceArray(1.72735e-05, dtype=float32), 0.1059999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2293, DeviceArray(1.7211685e-05, dtype=float32), 0.1049999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2294, DeviceArray(1.7120714e-05, dtype=float32), 0.1039999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2295, DeviceArray(1.7060756e-05, dtype=float32), 0.1029999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2296, DeviceArray(1.697419e-05, dtype=float32), 0.1019999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2297, DeviceArray(1.6913713e-05, dtype=float32), 0.1009999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2298, DeviceArray(1.68333e-05, dtype=float32), 0.0999999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2299, DeviceArray(1.6772532e-05, dtype=float32), 0.0989999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2300, DeviceArray(1.6696618e-05, dtype=float32), 0.0979999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2301, DeviceArray(1.663599e-05, dtype=float32), 0.0969999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2302, DeviceArray(1.6565611e-05, dtype=float32), 0.0959999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2303, DeviceArray(1.6503542e-05, dtype=float32), 0.0949999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2304, DeviceArray(1.6438811e-05, dtype=float32), 0.0939999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2305, DeviceArray(1.6376416e-05, dtype=float32), 0.0929999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2306, DeviceArray(1.6315938e-05, dtype=float32), 0.0919999999999987)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2307, DeviceArray(1.6253674e-05, dtype=float32), 0.09099999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2308, DeviceArray(1.619702e-05, dtype=float32), 0.08999999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2309, DeviceArray(1.6135886e-05, dtype=float32), 0.08899999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2310, DeviceArray(1.60812e-05, dtype=float32), 0.08799999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2311, DeviceArray(1.6022897e-05, dtype=float32), 0.08699999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2312, DeviceArray(1.5969043e-05, dtype=float32), 0.08599999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2313, DeviceArray(1.591391e-05, dtype=float32), 0.08499999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2314, DeviceArray(1.5860576e-05, dtype=float32), 0.08399999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2315, DeviceArray(1.5808779e-05, dtype=float32), 0.08299999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2316, DeviceArray(1.5756135e-05, dtype=float32), 0.08199999999999869)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2317, DeviceArray(1.5706652e-05, dtype=float32), 0.08099999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2318, DeviceArray(1.565598e-05, dtype=float32), 0.07999999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2319, DeviceArray(1.5607719e-05, dtype=float32), 0.07899999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2320, DeviceArray(1.5559497e-05, dtype=float32), 0.07799999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2321, DeviceArray(1.5512129e-05, dtype=float32), 0.07699999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2322, DeviceArray(1.5466323e-05, dtype=float32), 0.07599999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2323, DeviceArray(1.5420233e-05, dtype=float32), 0.07499999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2324, DeviceArray(1.5376007e-05, dtype=float32), 0.07399999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2325, DeviceArray(1.5332005e-05, dtype=float32), 0.07299999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2326, DeviceArray(1.5288875e-05, dtype=float32), 0.07199999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2327, DeviceArray(1.5246864e-05, dtype=float32), 0.07099999999999868)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2328, DeviceArray(1.5205051e-05, dtype=float32), 0.06999999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2329, DeviceArray(1.51645545e-05, dtype=float32), 0.06899999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2330, DeviceArray(1.5124578e-05, dtype=float32), 0.06799999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2331, DeviceArray(1.5085215e-05, dtype=float32), 0.06699999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2332, DeviceArray(1.5046935e-05, dtype=float32), 0.06599999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2333, DeviceArray(1.5009081e-05, dtype=float32), 0.06499999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2334, DeviceArray(1.4972103e-05, dtype=float32), 0.06399999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2335, DeviceArray(1.4935845e-05, dtype=float32), 0.06299999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2336, DeviceArray(1.4900164e-05, dtype=float32), 0.06199999999999867)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2337, DeviceArray(1.4865357e-05, dtype=float32), 0.060999999999998666)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2338, DeviceArray(1.48311865e-05, dtype=float32), 0.059999999999998666)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2339, DeviceArray(1.4797609e-05, dtype=float32), 0.058999999999998665)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2340, DeviceArray(1.476485e-05, dtype=float32), 0.057999999999998664)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2341, DeviceArray(1.47326755e-05, dtype=float32), 0.05699999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2342, DeviceArray(1.4701174e-05, dtype=float32), 0.05599999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2343, DeviceArray(1.4670401e-05, dtype=float32), 0.05499999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2344, DeviceArray(1.4640191e-05, dtype=float32), 0.05399999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2345, DeviceArray(1.4610661e-05, dtype=float32), 0.05299999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2346, DeviceArray(1.45818185e-05, dtype=float32), 0.05199999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2347, DeviceArray(1.4553556e-05, dtype=float32), 0.05099999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2348, DeviceArray(1.4525913e-05, dtype=float32), 0.04999999999999866)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2349, DeviceArray(1.44989635e-05, dtype=float32), 0.048999999999998656)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2350, DeviceArray(1.4472556e-05, dtype=float32), 0.047999999999998655)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2351, DeviceArray(1.4446793e-05, dtype=float32), 0.046999999999998654)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2352, DeviceArray(1.4421661e-05, dtype=float32), 0.04599999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2353, DeviceArray(1.4397103e-05, dtype=float32), 0.04499999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2354, DeviceArray(1.437314e-05, dtype=float32), 0.04399999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2355, DeviceArray(1.4349778e-05, dtype=float32), 0.04299999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2356, DeviceArray(1.43270345e-05, dtype=float32), 0.04199999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2357, DeviceArray(1.4304841e-05, dtype=float32), 0.04099999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2358, DeviceArray(1.4283227e-05, dtype=float32), 0.03999999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2359, DeviceArray(1.4262222e-05, dtype=float32), 0.03899999999999865)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2360, DeviceArray(1.4241778e-05, dtype=float32), 0.037999999999998646)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2361, DeviceArray(1.4221856e-05, dtype=float32), 0.036999999999998645)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2362, DeviceArray(1.4202564e-05, dtype=float32), 0.035999999999998644)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2363, DeviceArray(1.41838045e-05, dtype=float32), 0.03499999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2364, DeviceArray(1.4165622e-05, dtype=float32), 0.03399999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2365, DeviceArray(1.4147978e-05, dtype=float32), 0.03299999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2366, DeviceArray(1.4130878e-05, dtype=float32), 0.03199999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2367, DeviceArray(1.4114331e-05, dtype=float32), 0.03099999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2368, DeviceArray(1.4098349e-05, dtype=float32), 0.02999999999999864)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2369, DeviceArray(1.4082861e-05, dtype=float32), 0.028999999999998638)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2370, DeviceArray(1.4067968e-05, dtype=float32), 0.027999999999998637)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2371, DeviceArray(1.4053583e-05, dtype=float32), 0.026999999999998636)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2372, DeviceArray(1.4039753e-05, dtype=float32), 0.025999999999998635)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2373, DeviceArray(1.40264365e-05, dtype=float32), 0.024999999999998634)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2374, DeviceArray(1.4013641e-05, dtype=float32), 0.023999999999998634)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2375, DeviceArray(1.4001398e-05, dtype=float32), 0.022999999999998633)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2376, DeviceArray(1.3989665e-05, dtype=float32), 0.021999999999998632)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2377, DeviceArray(1.3978466e-05, dtype=float32), 0.02099999999999863)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2378, DeviceArray(1.3967803e-05, dtype=float32), 0.01999999999999863)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2379, DeviceArray(1.3957629e-05, dtype=float32), 0.01899999999999863)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2380, DeviceArray(1.3947975e-05, dtype=float32), 0.017999999999998628)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2381, DeviceArray(1.393885e-05, dtype=float32), 0.016999999999998627)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2382, DeviceArray(1.393024e-05, dtype=float32), 0.015999999999998626)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2383, DeviceArray(1.3922121e-05, dtype=float32), 0.014999999999998626)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2384, DeviceArray(1.39145495e-05, dtype=float32), 0.013999999999998625)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2385, DeviceArray(1.39075e-05, dtype=float32), 0.012999999999998624)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2386, DeviceArray(1.3900902e-05, dtype=float32), 0.011999999999998623)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2387, DeviceArray(1.3894853e-05, dtype=float32), 0.010999999999998622)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2388, DeviceArray(1.3889292e-05, dtype=float32), 0.009999999999998621)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2389, DeviceArray(1.3884234e-05, dtype=float32), 0.00899999999999862)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2390, DeviceArray(1.3879717e-05, dtype=float32), 0.00799999999999862)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2391, DeviceArray(1.3875672e-05, dtype=float32), 0.006999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2392, DeviceArray(1.3872157e-05, dtype=float32), 0.005999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2393, DeviceArray(1.38691275e-05, dtype=float32), 0.004999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2394, DeviceArray(1.3866608e-05, dtype=float32), 0.003999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2395, DeviceArray(1.3864592e-05, dtype=float32), 0.0029999999999986192)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2396, DeviceArray(1.3863087e-05, dtype=float32), 0.001999999999998619)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2397, DeviceArray(1.3862083e-05, dtype=float32), 0.0009999999999986192)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2398, DeviceArray(1.3861576e-05, dtype=float32), -1.3808398868775384e-15)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2471, DeviceArray(1.3741711e-05, dtype=float32), 0.1579999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2474, DeviceArray(1.34281245e-05, dtype=float32), 0.1549999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2477, DeviceArray(1.3180141e-05, dtype=float32), 0.1519999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2480, DeviceArray(1.2938164e-05, dtype=float32), 0.1489999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2483, DeviceArray(1.2705056e-05, dtype=float32), 0.1459999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2485, DeviceArray(1.2689309e-05, dtype=float32), 0.1439999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2486, DeviceArray(1.2488382e-05, dtype=float32), 0.1429999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2488, DeviceArray(1.2416745e-05, dtype=float32), 0.1409999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2489, DeviceArray(1.2290578e-05, dtype=float32), 0.1399999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2491, DeviceArray(1.2173016e-05, dtype=float32), 0.1379999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2492, DeviceArray(1.2110616e-05, dtype=float32), 0.1369999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2493, DeviceArray(1.2086751e-05, dtype=float32), 0.1359999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2494, DeviceArray(1.1961079e-05, dtype=float32), 0.1349999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2495, DeviceArray(1.1937825e-05, dtype=float32), 0.1339999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2496, DeviceArray(1.18682e-05, dtype=float32), 0.1329999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2497, DeviceArray(1.1782747e-05, dtype=float32), 0.1319999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2498, DeviceArray(1.1758871e-05, dtype=float32), 0.1309999999999986)
# Loss Updated!
#
# epoch: %3d loss: %.6f lr: %.6f (2499, DeviceArray(1.1668107e-05, dtype=float32), 0.1299999999999986)
# Loss Updated!

# %%
with open('/content/gdrive/My Drive/EX3_1_DEF.npy', 'wb') as f:
    np.save(f, bestParams2)

# %%
w1 = np.load('/content/gdrive/My Drive/EX3_1.npy', allow_pickle=True)

# %%
w2 = np.load('/content/gdrive/My Drive/EX3_1_DEF.npy', allow_pickle=True)

# %%
inputs = np.linspace(consts['t0'], consts['t1'], num=100)

# %%
with open('/content/gdrive/My Drive/EXAMPLE3_1.npy', 'wb') as f:
    np.save(f, {"consts": consts, "solution":w1, "defect": w2})

# %%
loss2(w1, inputs, consts)
# Out:
# DeviceArray(6.984263e-20, dtype=float32)

# %%
eX1 = []
eX2 = []
eL1 = []
eL2 = []
for t in inputs:
  eX1.append(nn_V(w2, t, consts)[0] - nn_V(w1, t, consts)[0])
  eX2.append(nn_V(w2, t, consts)[1] - nn_V(w1, t, consts)[1])
  eL1.append(nn_V(w2, t, consts)[2] - nn_V(w1, t, consts)[2])
  eL2.append(nn_V(w2, t, consts)[3] - nn_V(w1, t, consts)[3])

eX1 = np.array(eX1)
eL1 = np.array(eL1)
eX2 = np.array(eX2)
eL2 = np.array(eL2)

# %%
plt.plot(inputs, eX1)
plt.plot(inputs, eL1)
plt.plot(inputs, eX2)
plt.plot(inputs, eL2)
plt.show()

# %%
np.abs(eX1).max()
# Out:
# DeviceArray(0.00205755, dtype=float32)

# %%
np.abs(eX2).max()
# Out:
# DeviceArray(0.00184202, dtype=float32)

# %%
np.abs(eL1).max()
# Out:
# DeviceArray(0.00312361, dtype=float32)

# %%
np.abs(eL2).max()
# Out:
# DeviceArray(0.00166404, dtype=float32)

# %% [markdown]
# **SHOOTING**

# %%
def fun(t, y, c):
    phi = y[0]
    rho = y[1]
    L1 = y[2]
    L2 = y[3]

    H0 = L2*(-c['k']*rho + c['N']*phi*(1.-0.)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - rho/c['rhoMax'] * phi*(1.-0.)*c['v'])
    H1 = L2*(-c['k']*rho + c['N']*phi*(1.-0.9)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - phi*0.9*0.9 - rho/c['rhoMax'] * phi*(1.-0.9)*c['v'])

    utest = np.clip(0.5*(-L2*c['N']*c['rhoMax'] + rho*c['v'] - c['n']*rho*c['v'] + c['n']*L1*rho*c['v'])/(c['rhoMax']*(1. - c['n']+ c['n']*L1)),0., 0.9)
    Hu = L2*(-c['k']*rho + c['N']*phi*(1-utest)) - c['b']*phi*L1 + (1. - c['n'] + c['n']*L1)*(c['z']*phi - phi*utest*utest - rho/c['rhoMax'] * phi*(1.-utest)*c['v'])

    if (H0 > H1 and H0 > Hu):
      u = 0.0
    elif (H1 > H0 and H1 > Hu):
      u = 0.9
    else:
      u = utest

    dphi = (-c['b']*phi + c['n']*(c['z']*phi - phi*u*u - rho/c['rhoMax'] * phi*(1.-u)*c['v']))
    drho = (-c['k']*rho + c['N']*phi*(1.-u))

    dL1 = -(L2*c['N']*(1.-u) - c['b']*L1 + 
                   (1.-c['n']+c['n']*L1)*(c['z'] - u*u - rho/c['rhoMax'] * (1.-u)*c['v']))
    dL2 = -(-L2*c['k'] - 
                   ((1.-c['n']+c['n']*L1)*phi*(1.-u)*c['v'])/c['rhoMax'])
    
    return numpy.array([dphi, drho, dL1, dL2])

# %%
from scipy.integrate import solve_ivp

# %%
sol = solve_ivp(fun, (consts['t0'], consts['t1']), [1. ,0., -0.49307835, -0.15152481], method='RK45', args=(consts,))

# %%
sol.status
# Out:
# 0

# %%
sol.y
# Out:
# array([[ 1.00000000e+00,  9.99888912e-01,  9.98661433e-01,
#          9.75926484e-01,  7.49814764e-01,  5.32115597e-01,
#          2.41878478e-01,  1.03662560e-01,  6.75932440e-02],
#        [ 0.00000000e+00,  1.72424937e-03,  1.87170907e-02,
#          1.64085263e-01,  2.92918211e-01,  2.36585750e-01,
#          1.33675565e-01,  6.70329463e-02,  4.64364091e-02],
#        [-4.93078350e-01, -4.93992176e-01, -5.03119081e-01,
#         -5.93934318e-01, -9.50323961e-01, -1.40107035e+00,
#         -3.22085695e+00, -7.45169479e+00, -1.12167893e+01],
#        [-1.51524810e-01, -1.51274326e-01, -1.48829598e-01,
#         -1.30349655e-01, -1.49439042e-01, -2.29597336e-01,
#         -6.54535779e-01, -1.95072554e+00, -3.34226853e+00]])

# %%
sol.y[2:, -1]
# Out:
# array([-11.21678934,  -3.34226853])

# %%
def shootin_func(x, c):
    sol = solve_ivp(fun, (c['t0'], c['t1']), [c['ics'][0] ,c['ics'][1], x[0], x[1]], method='DOP853', args=(c,),atol =1e-8, rtol=1e-8)#DOP853
    if sol.status == -1:
      raise NotImplementedError
      
    return sol.y[2:, -1]

# %%
from scipy import optimize

# %%
optimize.root(shootin_func, [1.0, 1.0],method='hybr', args=(consts,),tol=1e-8)
# Out:
#     fjac: array([[-0.9496928,  0.313183 ],
#        [-0.313183 , -0.9496928]])
#      fun: array([-2.12157434e-06, -6.57604621e-06])
#  message: 'The solution converged.'
#     nfev: 37
#      qtf: array([-4.46620202e-08,  6.90966474e-06])
#        r: array([1.42331082e+03, 4.93541339e+02, 5.38919203e-01])
#   status: 1
#  success: True
#        x: array([ 0.40444848, -0.53546287])

# %%
sol = solve_ivp(fun, (consts['t0'], consts['t1']), [1. ,0., 0.00769373, -0.0021513], method='DOP853', args=(consts,), t_eval=inputs,atol =1e-8, rtol=1e-8)

# %%
sol.y[:, 0]
# Out:
# array([ 1.        ,  0.        ,  0.00769373, -0.0021513 ])

# %%
plt.plot(sol.t, numpy.swapaxes(sol.y, 1, 0))
# Out:
# [<matplotlib.lines.Line2D at 0x7fe1eac93198>,
#  <matplotlib.lines.Line2D at 0x7fe1eac932b0>,
#  <matplotlib.lines.Line2D at 0x7fe1eac93400>,
#  <matplotlib.lines.Line2D at 0x7fe1eac93550>]

# %%
u=[]
M0 = consts['M0']
M1 = consts['M1']
M2 = consts['M2']
for x in inputs:
  u.append(nn_V(w1, x, consts) )

# %%
u = np.array(u)
s = numpy.swapaxes(sol.y, 1, 0)

# %%
plt.plot(inputs, u[:, 0],'k', linewidth=2)
#plt.plot(sol.t, s[:, 0], linewidth=2)
#plt.legend(['предложенный метод'])
plt.gca().set_xlabel('t, мес.')
plt.gca().set_ylabel(r'$\phi$, у.е.')
plt.savefig('/content/gdrive/My Drive/ex3_phi_2.eps')
plt.savefig('/content/gdrive/My Drive/ex3_phi_2.png')

# %%
plt.plot(inputs, u[:, 1],'k', linewidth=2)
#plt.plot(sol.t, s[:, 1], linewidth=2)
#plt.legend(['предложенный метод', 'метод стрельбы'])
plt.gca().set_xlabel('t, мес.')
plt.gca().set_ylabel(r'$\rho$, мг/л')
plt.savefig('/content/gdrive/My Drive/ex3_rho_2.eps')
plt.savefig('/content/gdrive/My Drive/ex3_rho_2.png')

# %%
plt.plot(inputs, u[:, 2], linewidth=4)
#plt.plot(sol.t, s[:, 2], linewidth=2)
plt.legend(['предложенный метод', 'метод стрельбы'])
plt.gca().set_xlabel('t, мес.')
plt.gca().set_ylabel(r'$\lambda_1$')
plt.savefig('/content/gdrive/My Drive/ex3_L1.eps')
plt.savefig('/content/gdrive/My Drive/ex3_L1.png')
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.plot(inputs, u[:, 3], linewidth=4)
#plt.plot(sol.t, s[:, 3], linewidth=2)
plt.legend(['предложенный метод', 'метод стрельбы'])
plt.gca().set_xlabel('t, мес.')
plt.gca().set_ylabel(r'$\lambda_2$')
plt.savefig('/content/gdrive/My Drive/ex3_L2.eps')
plt.savefig('/content/gdrive/My Drive/ex3_L2.png')
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
s = []
for t, y in zip(sol.t, sol.y.swapaxes(1, 0)):
  s.append(nn_V(w1, t, consts) - y)

# %%
s = numpy.abs(numpy.array(s))

# %%
s[:, 0].max()
# Out:
# 0.194594

# %%
s[:, 1].max()
# Out:
# 0.43652672

# %%
s[:, 2].max()
# Out:
# 25.732609

# %%
s[:, 3].max()
# Out:
# 1.7672856
